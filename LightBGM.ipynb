# %%
import os
import numpy as np
import pandas as pd
from scipy.stats import skew, kurtosis
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
from tqdm import tqdm

import lightgbm as lgb
from xgboost import XGBClassifier

# %%
# origin code
N_FFT = 10
def extract_features(fp):
    df = pd.read_csv(fp, sep=' ', header=None,
                     names=['Ax','Ay','Az','Gx','Gy','Gz'],
                     dtype=float, on_bad_lines='skip').dropna()
    
    feats = {}
    for col in df.columns:
        v = df[col].values
        feats[f'{col}_mean']     = v.mean()
        feats[f'{col}_std']      = v.std()
        feats[f'{col}_max']      = v.max()
        feats[f'{col}_min']      = v.min()
        feats[f'{col}_range']    = v.max() - v.min()
        feats[f'{col}_skew']     = skew(v)
        feats[f'{col}_kurtosis'] = kurtosis(v)
        feats[f'{col}_zcross']   = np.sum(v[:-1]*v[1:] < 0)
        feats[f'{col}_rms']      = np.sqrt(np.mean(v**2)) # 新增特徵

    mag = np.sqrt(df['Ax']**2 + df['Ay']**2 + df['Az']**2)
    feats['acc_mag_mean'] = mag.mean()
    feats['acc_mag_std']  = mag.std()

    for col in df.columns:
        signal = df[col].values
        ps = np.abs(np.fft.rfft(df[col].values))**2
        ps_norm = ps / np.sum(ps + 1e-8)  # 避免除以零
        for i in range(1, N_FFT+1):
            feats[f'{col}_fft{i}'] = ps[i]
            feats[f'{col}_psd{i}'] = ps[i] / len(signal)  # PSD：功率密度，新增特徵
        feats[f'{col}_entropy'] = -np.sum(ps_norm * np.log(ps_norm + 1e-8))  # Spectral Entropy，新增特徵
    return feats

# %% [markdown]
# 1. 每筆txt檔有27次揮拍。
# 2. 利用 np.linspace(0, len(df), 28) 切割出 27 段 index
# 3. 每段套用 extract_features()，回傳一個 list of dict
# 4. 對所有 dict 做特徵平均，回傳單一 dict（代表整份資料）

# %%
# change code (27feature average)
N_FFT = 10
def extract_features_segment_avg(fp, n_segment=27):
    df = pd.read_csv(fp, sep=' ', header=None,
                     names=['Ax','Ay','Az','Gx','Gy','Gz'],
                     dtype=float, on_bad_lines='skip').dropna()

    segment_indices = np.linspace(0, len(df), n_segment + 1, dtype=int)
    features_list = []

    for i in range(n_segment):
        start, end = segment_indices[i], segment_indices[i+1]
        if end - start < 10:  # 太短不計
            continue
        df_seg = df.iloc[start:end]
        feats = {}

        for col in df_seg.columns:
            v = df_seg[col].values
            feats[f'{col}_mean']     = v.mean()
            feats[f'{col}_std']      = v.std()
            feats[f'{col}_max']      = v.max()
            feats[f'{col}_min']      = v.min()
            feats[f'{col}_range']    = v.max() - v.min()
            feats[f'{col}_skew']     = skew(v)
            feats[f'{col}_kurtosis'] = kurtosis(v)
            feats[f'{col}_zcross']   = np.sum(v[:-1]*v[1:] < 0)
            feats[f'{col}_rms']      = np.sqrt(np.mean(v**2))
        
        mag = np.sqrt(df_seg['Ax']**2 + df_seg['Ay']**2 + df_seg['Az']**2)
        feats['acc_mag_mean'] = mag.mean()
        feats['acc_mag_std']  = mag.std()

        for col in df_seg.columns:
            signal = df_seg[col].values
            ps = np.abs(np.fft.rfft(signal))**2
            ps_norm = ps / np.sum(ps + 1e-8)
            for j in range(1, N_FFT + 1):
                if j < len(ps):
                    feats[f'{col}_fft{j}'] = ps[j]
                    feats[f'{col}_psd{j}'] = ps[j] / len(signal)
                else:
                    feats[f'{col}_fft{j}'] = 0.0
                    feats[f'{col}_psd{j}'] = 0.0
            feats[f'{col}_entropy'] = -np.sum(ps_norm * np.log(ps_norm + 1e-8))

        features_list.append(feats)

    # 對 27 段特徵取平均
    df_feats = pd.DataFrame(features_list)
    avg_feats = df_feats.mean(axis=0).to_dict()
    return avg_feats

# %%
# change code (27feature)
N_FFT = 5
def extract_features_segments(fp, n_segment=27):
    df = pd.read_csv(fp, sep=' ', header=None,
                     names=['Ax','Ay','Az','Gx','Gy','Gz'],
                     dtype=float, on_bad_lines='skip').dropna()

    segment_indices = np.linspace(0, len(df), n_segment + 1, dtype=int)
    features_list = []

    for i in range(n_segment):
        start, end = segment_indices[i], segment_indices[i+1]
        if end - start < 10:
            continue  # 若片段太短則略過
        df_seg = df.iloc[start:end]
        feats = {}

        for col in df_seg.columns:
            v = df_seg[col].values
            feats[f'{col}_mean']     = v.mean()
            feats[f'{col}_std']      = v.std()
            feats[f'{col}_max']      = v.max()
            feats[f'{col}_min']      = v.min()
            feats[f'{col}_range']    = v.max() - v.min()
            feats[f'{col}_skew']     = skew(v)
            feats[f'{col}_kurtosis'] = kurtosis(v)
            feats[f'{col}_zcross']   = np.sum(v[:-1]*v[1:] < 0)
            feats[f'{col}_rms']      = np.sqrt(np.mean(v**2))

        mag = np.sqrt(df_seg['Ax']**2 + df_seg['Ay']**2 + df_seg['Az']**2)
        feats['acc_mag_mean'] = mag.mean()
        feats['acc_mag_std']  = mag.std()

        for col in df_seg.columns:
            signal = df_seg[col].values
            ps = np.abs(np.fft.rfft(signal))**2
            ps_norm = ps / np.sum(ps + 1e-8)
            for j in range(1, N_FFT + 1):
                if j < len(ps):
                    feats[f'{col}_fft{j}'] = ps[j]
                    feats[f'{col}_psd{j}'] = ps[j] / len(signal)
                else:
                    feats[f'{col}_fft{j}'] = 0.0
                    feats[f'{col}_psd{j}'] = 0.0
            feats[f'{col}_entropy'] = -np.sum(ps_norm * np.log(ps_norm + 1e-8))

        features_list.append(feats)

    return features_list  # ✅ 直接回傳 27 筆（或部分）segment 特徵

# %%
# 先在全域讀取 test_info，避免 NameError
test_info = pd.read_csv(os.path.join('./data/39_Test_Dataset/test_info.csv'))

# %%
# origin code
info = pd.read_csv(os.path.join('./data/39_Training_Dataset/train_info.csv'))
X_list, y_gender, y_hand, y_years, y_level = [], [], [], [], []
for _, r in info.iterrows():
    fp = os.path.join('./data/39_Training_Dataset/train_data', f"{r['unique_id']}.txt")

    X_list.append(extract_features(fp)) # origin code
    # X_list.append(extract_features_segment_avg(fp)) # change code (27feature avg)
    y_gender.append(1 if r['gender']==1 else 0)
    y_hand.append(1 if r['hold racket handed']==1 else 0)
    y_years.append(r['play years'])
    y_level.append(r['level'] - 2)
X_train = pd.DataFrame(X_list)

# %%
# change code (27feature train)
# 定義 flatten 函數（可放在 utils.py 或 notebook 前面）
def flatten_train_segments(info_csv_path, data_folder, extract_fn):
    info = pd.read_csv(info_csv_path)
    X_list, y_gender, y_hand, y_years, y_level = [], [], [], [], []

    for _, r in info.iterrows():
        fp = os.path.join(data_folder, f"{r['unique_id']}.txt")
        segments = extract_fn(fp)
        for seg in segments:
            X_list.append(seg)
            y_gender.append(r['gender'])  # ✅ 男生=1, 女生=0
            y_hand.append(r['hold racket handed'])  # ✅ 右手=1, 左手=0
            y_years.append(r['play years'])
            y_level.append(r['level'] - 2)

    X_train = pd.DataFrame(X_list)
    return X_train, y_gender, y_hand, y_years, y_level

X_train, y_gender, y_hand, y_years, y_level = flatten_train_segments(
    info_csv_path='./data/39_Training_Dataset/train_info.csv',
    data_folder='./data/39_Training_Dataset/train_data',
    extract_fn=extract_features_segments
)

# %%
# change code (change parameter & learning rate decay)
def cv_predict(X, y, params, objective, num_class=None):
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    # （此處改用全域預先讀好的 test_info）
    X_test = pd.DataFrame(
        # [extract_features(os.path.join('./data/39_Test_Dataset/test_data',f"{r['unique_id']}.txt")) for _, r in test_info.iterrows()], # origin code
        [extract_features_segment_avg(os.path.join('./data/39_Test_Dataset/test_data',f"{r['unique_id']}.txt")) for _, r in test_info.iterrows()], # change code(27feature avg)
        index=test_info['unique_id']
    )
    test_pred = (np.zeros((len(X_test), num_class))
                 if num_class else np.zeros(len(X_test)))

    aucs = []
    for fold, (ti, vi) in enumerate(skf.split(X, y)):
        X_tr, X_va = X.iloc[ti], X.iloc[vi]
        y_tr, y_va = np.array(y)[ti], np.array(y)[vi]

        clf = lgb.LGBMClassifier(**params)
        clf.set_params(objective=objective)
        if num_class:
            clf.set_params(num_class=num_class)
        # 根據任務選擇 eval_metric
        eval_metric = 'auc' if num_class is None else 'multi_logloss'

        learning_rates = lambda iter: 0.07 * (0.99 ** iter)

        clf.fit(
            X_tr, y_tr,
            eval_set=[(X_va, y_va)],
            eval_metric=eval_metric,
            callbacks=[
                lgb.early_stopping(stopping_rounds=50),
                lgb.log_evaluation(period=10),
                lgb.reset_parameter(learning_rate=learning_rates)
            ]
        )

        va_pred = clf.predict_proba(X_va)
        fold_auc = (roc_auc_score(y_va, va_pred[:,1])
                    if num_class is None
                    else roc_auc_score(y_va, va_pred,
                                       multi_class='ovr', average='micro'))
        print(f"Fold{fold} AUC = {fold_auc:.6f}")
        aucs.append(fold_auc)

        if num_class:
            test_pred += clf.predict_proba(X_test) / skf.n_splits
        else:
            test_pred += clf.predict_proba(X_test)[:,1] / skf.n_splits

    print(f"Mean CV AUC = {np.mean(aucs):.6f}\n")
    return test_pred

params = {
    'n_estimators': 1000,
    'learning_rate': 0.05,
    'num_leaves': 31,
    'feature_fraction': 0.8,
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
    'lambda_l1': 1.0,                # L1 正則化（加強稀疏性）
    'lambda_l2': 1.0,                # L2 正則化（防止權重爆炸）
    'verbose': -1
}


# 執行四個任務的 CV
pred_gender = cv_predict(X_train, y_gender, params,   'binary',    None)

params = {
    'n_estimators': 2000,
    'learning_rate': 0.07,
    'num_leaves': 31,
    'feature_fraction': 0.8,
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
    'lambda_l1': 1.0,                # L1 正則化（加強稀疏性）
    'lambda_l2': 1.0,                # L2 正則化（防止權重爆炸）
    'verbose': -1
}  

pred_years  = cv_predict(X_train, y_years,  params,   'multiclass',3)
pred_level  = cv_predict(X_train, y_level,  params,   'multiclass',4)

params = {
    'n_estimators': 1000,            # 最多迭代 1000 棵樹
    'learning_rate': 0.07,           # 初始學習率（會使用動態調整）
    'num_leaves': 31,                # 每棵樹的最大葉節點數
    'max_depth': 7,                  # 每棵樹的最大深度（控制模型複雜度）
    'feature_fraction': 0.8,         # 每棵樹隨機選用的特徵比例
    'bagging_fraction': 0.8,         # 每棵樹隨機使用的資料比例
    'bagging_freq': 5,               # 每5次 boosting 做一次 row sampling
    'lambda_l1': 1.0,                # L1 正則化（加強稀疏性）
    'lambda_l2': 1.0,                # L2 正則化（防止權重爆炸）
    'verbose': -1                    # 關閉訓練輸出
}

print(f"learning_rate: {params['learning_rate']}")
print(f"num_leaves: {params['num_leaves']}")
print(f"max_depth: {params['max_depth']}")


pred_hand   = cv_predict(X_train, y_hand,   params,   'binary',    None)

# params = {
#     'n_estimators': 1000,            # 最多迭代 1000 棵樹
#     'learning_rate': 0.07,           # 初始學習率（會使用動態調整）
#     'num_leaves': 63,                # 每棵樹的最大葉節點數
#     'max_depth': 0,                  # 每棵樹的最大深度（控制模型複雜度）
#     'feature_fraction': 0.8,         # 每棵樹隨機選用的特徵比例
#     'bagging_fraction': 0.8,         # 每棵樹隨機使用的資料比例
#     'bagging_freq': 5,               # 每5次 boosting 做一次 row sampling
#     'lambda_l1': 1.0,                # L1 正則化（加強稀疏性）
#     'lambda_l2': 1.0,                # L2 正則化（防止權重爆炸）
#     'verbose': -1                    # 關閉訓練輸出
# }

# print(f"learning_rate: {params['learning_rate']}")
# print(f"num_leaves: {params['num_leaves']}")
# print(f"max_depth: {params['max_depth']}")

# pred_years  = cv_predict(X_train, y_years,  params,   'multiclass',3)

# params = {
#     'n_estimators': 1000,            # 最多迭代 1000 棵樹
#     'learning_rate': 0.07,           # 初始學習率（會使用動態調整）
#     'num_leaves': 63,                # 每棵樹的最大葉節點數
#     'max_depth': 0,                  # 每棵樹的最大深度（控制模型複雜度）
#     'feature_fraction': 0.8,         # 每棵樹隨機選用的特徵比例
#     'bagging_fraction': 0.8,         # 每棵樹隨機使用的資料比例
#     'bagging_freq': 5,               # 每5次 boosting 做一次 row sampling
#     'lambda_l1': 1.0,                # L1 正則化（加強稀疏性）
#     'lambda_l2': 1.0,                # L2 正則化（防止權重爆炸）
#     'verbose': -1                    # 關閉訓練輸出
# }

# print(f"learning_rate: {params['learning_rate']}")
# print(f"num_leaves: {params['num_leaves']}")
# print(f"max_depth: {params['max_depth']}")

# pred_level  = cv_predict(X_train, y_level,  params,   'multiclass',4)

# %%
# origin code
def cv_predict(X, y, params, objective, num_class=None):
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    # （此處改用全域預先讀好的 test_info）
    X_test = pd.DataFrame(
        [extract_features(os.path.join('./data/39_Test_Dataset/test_data',f"{r['unique_id']}.txt"))for _, r in test_info.iterrows()], # origin code
        # [extract_features_segment_avg(os.path.join('./data/39_Test_Dataset/test_data',f"{r['unique_id']}.txt")) for _, r in test_info.iterrows()], # change code(27feature avg)
        index=test_info['unique_id']
    )
    test_pred = (np.zeros((len(X_test), num_class))
                 if num_class else np.zeros(len(X_test)))

    aucs = []
    for fold, (ti, vi) in enumerate(skf.split(X, y)):
        X_tr, X_va = X.iloc[ti], X.iloc[vi]
        y_tr, y_va = np.array(y)[ti], np.array(y)[vi]

        clf = lgb.LGBMClassifier(**params)

        clf.set_params(objective=objective)
        if num_class:
            clf.set_params(num_class=num_class)
        # 根據任務選擇 eval_metric
        eval_metric = 'auc' if num_class is None else 'multi_logloss'
        
        clf.fit(
            X_tr, y_tr,
            eval_set=[(X_va, y_va)],
            eval_metric=eval_metric,
            callbacks=[
                lgb.early_stopping(stopping_rounds=50),
                lgb.log_evaluation(period=0)
            ]
        )


        va_pred = clf.predict_proba(X_va)
        fold_auc = (roc_auc_score(y_va, va_pred[:,1])
                    if num_class is None
                    else roc_auc_score(y_va, va_pred,
                                       multi_class='ovr', average='micro'))
        print(f"Fold{fold} AUC = {fold_auc:.6f}")
        aucs.append(fold_auc)

        if num_class:
            test_pred += clf.predict_proba(X_test) / skf.n_splits
        else:
            test_pred += clf.predict_proba(X_test)[:,1] / skf.n_splits


    print(f"Mean CV AUC = {np.mean(aucs):.6f}\n")
    return test_pred

# %%
# change code (27feature test)
def cv_predict(X, y, params, objective, num_class=None, test_info=None, test_folder='./data/39_Test_Dataset/test_data'):
    assert test_info is not None, "請提供 test_info"

    # 型別安全轉換
    X = X.apply(pd.to_numeric, errors='coerce').fillna(0)

    # 預先紀錄測試預測
    X_test_list = []
    test_id_list = []
    skipped_ids = []

    # for _, r in test_info.iterrows():
    for _, r in tqdm(test_info.iterrows(), total=len(test_info)):
        uid = r['unique_id']
        path = os.path.join(test_folder, f"{uid}.txt")
        try:
            segs = extract_features_segments(path)
        except:
            segs = []
        if not segs:
            skipped_ids.append(uid)
            continue
        X_test_list.extend(segs)
        test_id_list.extend([uid] * len(segs))

    X_test = pd.DataFrame(X_test_list).apply(pd.to_numeric, errors='coerce').fillna(0)

    # 對齊欄位
    common_cols = [col for col in X.columns if col in X_test.columns]
    if len(common_cols) == 0:
        raise ValueError("❌ 訓練與測試無共同特徵")
    X = X[common_cols]
    X_test = X_test[common_cols]

    # 建立模型
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    aucs, test_pred_all = [], []

    for fold, (ti, vi) in enumerate(skf.split(X, y)):
        X_tr, X_va = X.iloc[ti], X.iloc[vi]
        y_tr, y_va = np.array(y)[ti], np.array(y)[vi]

        clf = lgb.LGBMClassifier(**params)
        clf.set_params(objective=objective)
        if num_class: clf.set_params(num_class=num_class)

        clf.fit(
            X_tr, y_tr,
            eval_set=[(X_va, y_va)],
            eval_metric='auc' if num_class is None else 'multi_logloss',
            callbacks=[
                lgb.early_stopping(stopping_rounds=50),
                lgb.log_evaluation(period=0)
            ]
        )

        va_pred = clf.predict_proba(X_va)
        if num_class is None:
            auc = roc_auc_score(y_va, va_pred[:, 1])
        else:
            auc = roc_auc_score(y_va, va_pred, multi_class='ovr', average='micro')
        aucs.append(auc)
        print(f"Fold{fold} AUC = {auc:.6f}")

        test_pred_all.append(clf.predict_proba(X_test))

    # 平均所有 fold 的測試預測
    test_pred_avg = sum(test_pred_all) / len(test_pred_all)
    pred_df = pd.DataFrame(test_pred_avg)
    pred_df['unique_id'] = test_id_list

    # 根據 unique_id 群組統整每份檔案的預測
    final_pred_dict = {}

    # if num_class:
    #     for uid, group in pred_df.groupby('unique_id'):
    #         arr = group.drop(columns='unique_id').values
    #         top_class = np.argmax(np.bincount(np.argmax(arr, axis=1)))
    #         best_idx = np.argmax(arr[:, top_class])
    #         final_pred_dict[uid] = arr[best_idx]
    # else:
    #     for uid, group in pred_df.groupby('unique_id'):
    #         probs = group[0].values
    #         votes = (probs > 0.5).astype(int)
    #         maj_class = np.bincount(votes).argmax()
    #         best_idx = np.argmax(probs) if maj_class == 1 else np.argmin(probs)
    #         final_pred_dict[uid] = probs[best_idx]

    if num_class:
        for uid, group in pred_df.groupby('unique_id'):
            arr = group.drop(columns='unique_id').values
            final_pred_dict[uid] = arr.mean(axis=0)
    else:
        for uid, group in pred_df.groupby('unique_id'):
            probs = group[0].values
            final_pred_dict[uid] = probs.mean()


    # 遍歷 test_info 建立對應預測值，缺失檔案補預設值
    # pred_id = test_info['unique_id'].tolist()
    # if num_class:
    #     default_pred = [1.0 / num_class] * num_class
    #     final_pred = np.array([
    #         final_pred_dict.get(uid, default_pred)
    #         for uid in pred_id
    #     ])
    # else:
    #     final_pred = np.array([
    #         final_pred_dict.get(uid, 0.0)
    #         for uid in pred_id
    #     ])

    pred_id = test_info['unique_id'].tolist()

    if num_class:
        # 建立補值向量 = 所有預測值的平均（shape: [num_class]）
        all_preds = np.array(list(final_pred_dict.values()))
        avg_pred = all_preds.mean(axis=0)  # 各類平均機率向量

        final_pred = np.array([
            final_pred_dict.get(uid, avg_pred)
            for uid in pred_id
        ])
    else:
        # 建立補值 scalar = 所有預測的平均機率
        all_probs = np.array(list(final_pred_dict.values()))
        avg_prob = all_probs.mean()

        final_pred = np.array([
            final_pred_dict.get(uid, avg_prob)
            for uid in pred_id
        ])


    print(f"✅ 完成預測，共 {len(final_pred)} 筆，平均 AUC: {np.mean(aucs):.6f}")
    return final_pred, pred_id

# %%
params = { 
    'n_estimators': 1000,
    'learning_rate': 0.05,
    'num_leaves': 31,
    'feature_fraction': 0.8,
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
    'lambda_l1': 1.0,                # L1 正則化（加強稀疏性）
    'lambda_l2': 1.0,                # L2 正則化（防止權重爆炸）
    'verbose': -1
}

# origin code
# 執行四個任務的 CV
pred_gender = cv_predict(X_train, y_gender, params,   'binary',    None)
pred_hand   = cv_predict(X_train, y_hand,   params,   'binary',    None)
pred_years  = cv_predict(X_train, y_years,  params,   'multiclass',3)
pred_level  = cv_predict(X_train, y_level,  params,   'multiclass',4)

# # change code (27feature test)
# # 注意：test_info 是你之前已經用 pd.read_csv() 讀入的測試 meta 資訊
# pred_gender, pred_id       = cv_predict(X_train, y_gender, params, 'binary', None, test_info=test_info)
# pred_hand, _               = cv_predict(X_train, y_hand,   params, 'binary', None, test_info=test_info)
# pred_years, _              = cv_predict(X_train, y_years,  params, 'multiclass', 3, test_info=test_info)
# pred_level, _              = cv_predict(X_train, y_level,  params, 'multiclass', 4, test_info=test_info)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 15
#       1 params = {
#       2     'n_estimators': 1000,
#       3     'learning_rate': 0.05,
#    (...)     10     'verbose': -1
#      11 }
#      13 # origin code
#      14 # 執行四個任務的 CV
# ---> 15 pred_gender = cv_predict(X_train, y_gender, params,   'binary',    None)
#      16 pred_hand   = cv_predict(X_train, y_hand,   params,   'binary',    None)
#      17 pred_years  = cv_predict(X_train, y_years,  params,   'multiclass',3)
#
# Cell In[11], line 31, in cv_predict(X, y, params, objective, num_class)
#      28     eval_metric = 'auc'
#      30 # 訓練模型（相容 XGBoost 3.0.2）
# ---> 31 clf.fit(
#      32     X_tr, y_tr,
#      33     eval_set=[(X_va, y_va)],
#      34     early_stopping_rounds=50,
#      35     eval_metric=eval_metric,
#      36 )
#      38 # 預測與 AUC 計算
#      39 va_pred = clf.predict_proba(X_va)
#
# File ~/anaconda3/envs/ML311/lib/python3.11/site-packages/xgboost/core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# TypeError: XGBClassifier.fit() got an unexpected keyword argument 'early_stopping_rounds'

# %%
# XGboost
def cv_predict(X, y, params, objective, num_class=None):
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

    # 準備測試資料
    X_test = pd.DataFrame(
        [extract_features(os.path.join('./data/39_Test_Dataset/test_data', f"{r['unique_id']}.txt"))
         for _, r in test_info.iterrows()],
        index=test_info['unique_id']
    )
    test_pred = (np.zeros((len(X_test), num_class)) if num_class else np.zeros(len(X_test)))

    aucs = []

    for fold, (ti, vi) in enumerate(skf.split(X, y)):
        X_tr, X_va = X.iloc[ti], X.iloc[vi]
        y_tr, y_va = np.array(y)[ti], np.array(y)[vi]

        # 建立分類器
        clf = XGBClassifier(**params)

        # 多分類設定
        if objective == 'multiclass':
            clf.set_params(objective='multi:softprob', num_class=num_class)
            eval_metric = 'mlogloss'
        else:
            clf.set_params(objective='binary:logistic')
            eval_metric = 'auc'

        # 訓練模型（相容 XGBoost 3.0.2）
        clf.fit(
            X_tr, y_tr,
            eval_set=[(X_va, y_va)]
        )

        # 預測與 AUC 計算
        va_pred = clf.predict_proba(X_va)
        fold_auc = (roc_auc_score(y_va, va_pred[:, 1])
                    if num_class is None
                    else roc_auc_score(y_va, va_pred, multi_class='ovr', average='micro'))
        print(f"Fold{fold} AUC = {fold_auc:.6f}")
        aucs.append(fold_auc)

        # 測試預測
        test_prob = clf.predict_proba(X_test)
        if num_class:
            test_pred += test_prob / skf.n_splits
        else:
            test_pred += test_prob[:, 1] / skf.n_splits

    print(f"Mean CV AUC = {np.mean(aucs):.6f}\n")
    return test_pred

params = { 
    'n_estimators': 1000,
    'learning_rate': 0.05,
    'max_depth': 7,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'reg_alpha': 1.0,
    'reg_lambda': 1.0,
    'use_label_encoder': False,
    'verbosity': 0
}

pred_gender = cv_predict(X_train, y_gender, params,   'binary',    None)
pred_hand   = cv_predict(X_train, y_hand,   params,   'binary',    None)
pred_years  = cv_predict(X_train, y_years,  params,   'multiclass',3)
pred_level  = cv_predict(X_train, y_level,  params,   'multiclass',4)
# Out:
# [0]	validation_0-logloss:0.42541
# [1]	validation_0-logloss:0.40261
# [2]	validation_0-logloss:0.38068
# [3]	validation_0-logloss:0.36134
# [4]	validation_0-logloss:0.34484
# [5]	validation_0-logloss:0.33224
# [6]	validation_0-logloss:0.32092
# [7]	validation_0-logloss:0.30782
# [8]	validation_0-logloss:0.29240
# [9]	validation_0-logloss:0.27795
# [10]	validation_0-logloss:0.26623
# [11]	validation_0-logloss:0.25499
# [12]	validation_0-logloss:0.24554
# [13]	validation_0-logloss:0.23587
# [14]	validation_0-logloss:0.22644
# [15]	validation_0-logloss:0.21811
# [16]	validation_0-logloss:0.21073
# [17]	validation_0-logloss:0.20337
# [18]	validation_0-logloss:0.19642
# [19]	validation_0-logloss:0.19007
# [20]	validation_0-logloss:0.18403
# [21]	validation_0-logloss:0.17765
# [22]	validation_0-logloss:0.17201
# [23]	validation_0-logloss:0.16602
# [24]	validation_0-logloss:0.16117
# [25]	validation_0-logloss:0.15691
# [26]	validation_0-logloss:0.15148
# [27]	validation_0-logloss:0.14706
# [28]	validation_0-logloss:0.14312
# [29]	validation_0-logloss:0.13971
# [30]	validation_0-logloss:0.13678
# [31]	validation_0-logloss:0.13325
# [32]	validation_0-logloss:0.12963
# [33]	validation_0-logloss:0.12667
# [34]	validation_0-logloss:0.12349
# [35]	validation_0-logloss:0.12022
# [36]	validation_0-logloss:0.11738
# [37]	validation_0-logloss:0.11497
# [38]	validation_0-logloss:0.11218
# [39]	validation_0-logloss:0.10961
# [40]	validation_0-logloss:0.10754
# [41]	validation_0-logloss:0.10480
# [42]	validation_0-logloss:0.10239
# [43]	validation_0-logloss:0.10037
# [44]	validation_0-logloss:0.09856
# [45]	validation_0-logloss:0.09679
# [46]	validation_0-logloss:0.09508
# [47]	validation_0-logloss:0.09358
# [48]	validation_0-logloss:0.09230
# [49]	validation_0-logloss:0.09099
# [50]	validation_0-logloss:0.08930
# [51]	validation_0-logloss:0.08781
# [52]	validation_0-logloss:0.08632
# [53]	validation_0-logloss:0.08523
# [54]	validation_0-logloss:0.08403
# [55]	validation_0-logloss:0.08278
# [56]	validation_0-logloss:0.08191
# [57]	validation_0-logloss:0.08073
# [58]	validation_0-logloss:0.07972
# [59]	validation_0-logloss:0.07888
# [60]	validation_0-logloss:0.07800
# [61]	validation_0-logloss:0.07672
# [62]	validation_0-logloss:0.07613
# [63]	validation_0-logloss:0.07527
# [64]	validation_0-logloss:0.07452
# [65]	validation_0-logloss:0.07360
# [66]	validation_0-logloss:0.07259
# [67]	validation_0-logloss:0.07172
# [68]	validation_0-logloss:0.07091
# [69]	validation_0-logloss:0.07044
# [70]	validation_0-logloss:0.06980
# [71]	validation_0-logloss:0.06932
# [72]	validation_0-logloss:0.06900
# [73]	validation_0-logloss:0.06828
# [74]	validation_0-logloss:0.06766
# [75]	validation_0-logloss:0.06720
# [76]	validation_0-logloss:0.06645
# [77]	validation_0-logloss:0.06617
# [78]	validation_0-logloss:0.06610
# [79]	validation_0-logloss:0.06575
# [80]	validation_0-logloss:0.06537
# [81]	validation_0-logloss:0.06527
# [82]	validation_0-logloss:0.06455
# [83]	validation_0-logloss:0.06398
# [84]	validation_0-logloss:0.06356
# [85]	validation_0-logloss:0.06317
# [86]	validation_0-logloss:0.06285
# [87]	validation_0-logloss:0.06232
# [88]	validation_0-logloss:0.06172
# [89]	validation_0-logloss:0.06144
# [90]	validation_0-logloss:0.06108
# [91]	validation_0-logloss:0.06056
# [92]	validation_0-logloss:0.05984
# [93]	validation_0-logloss:0.05950
# [94]	validation_0-logloss:0.05910
# [95]	validation_0-logloss:0.05866
# [96]	validation_0-logloss:0.05861
# [97]	validation_0-logloss:0.05829
# [98]	validation_0-logloss:0.05822
# [99]	validation_0-logloss:0.05787
# [100]	validation_0-logloss:0.05751
# [101]	validation_0-logloss:0.05744
# [102]	validation_0-logloss:0.05729
# [103]	validation_0-logloss:0.05704
# [104]	validation_0-logloss:0.05699
# [105]	validation_0-logloss:0.05694
# [106]	validation_0-logloss:0.05663
# [107]	validation_0-logloss:0.05625
# [108]	validation_0-logloss:0.05601
# [109]	validation_0-logloss:0.05568
# [110]	validation_0-logloss:0.05542
# [111]	validation_0-logloss:0.05519
# [112]	validation_0-logloss:0.05511
# [113]	validation_0-logloss:0.05486
# [114]	validation_0-logloss:0.05472
# [115]	validation_0-logloss:0.05445
# [116]	validation_0-logloss:0.05419
# [117]	validation_0-logloss:0.05412
# [118]	validation_0-logloss:0.05383
# [119]	validation_0-logloss:0.05388
# [120]	validation_0-logloss:0.05392
# [121]	validation_0-logloss:0.05376
# [122]	validation_0-logloss:0.05355
# [123]	validation_0-logloss:0.05348
# [124]	validation_0-logloss:0.05324
# [125]	validation_0-logloss:0.05313
# [126]	validation_0-logloss:0.05291
# [127]	validation_0-logloss:0.05279
# [128]	validation_0-logloss:0.05280
# [129]	validation_0-logloss:0.05275
# [130]	validation_0-logloss:0.05258
# [131]	validation_0-logloss:0.05241
# [132]	validation_0-logloss:0.05220
# [133]	validation_0-logloss:0.05211
# [134]	validation_0-logloss:0.05191
# [135]	validation_0-logloss:0.05197
# [136]	validation_0-logloss:0.05199
# [137]	validation_0-logloss:0.05174
# [138]	validation_0-logloss:0.05169
# [139]	validation_0-logloss:0.05155
# [140]	validation_0-logloss:0.05108
# [141]	validation_0-logloss:0.05090
# [142]	validation_0-logloss:0.05084
# [143]	validation_0-logloss:0.05076
# [144]	validation_0-logloss:0.05067
# [145]	validation_0-logloss:0.05063
# [146]	validation_0-logloss:0.05048
# [147]	validation_0-logloss:0.05039
# [148]	validation_0-logloss:0.05042
# [149]	validation_0-logloss:0.05027
# [150]	validation_0-logloss:0.05019
# [151]	validation_0-logloss:0.05006
# [152]	validation_0-logloss:0.04978
# [153]	validation_0-logloss:0.04967
# [154]	validation_0-logloss:0.04962
# [155]	validation_0-logloss:0.04938
# [156]	validation_0-logloss:0.04934
# [157]	validation_0-logloss:0.04917
# [158]	validation_0-logloss:0.04901
# [159]	validation_0-logloss:0.04898
# [160]	validation_0-logloss:0.04891
# [161]	validation_0-logloss:0.04872
# [162]	validation_0-logloss:0.04868
# [163]	validation_0-logloss:0.04868
# [164]	validation_0-logloss:0.04867
# [165]	validation_0-logloss:0.04858
# [166]	validation_0-logloss:0.04861
# [167]	validation_0-logloss:0.04847
# [168]	validation_0-logloss:0.04837
# [169]	validation_0-logloss:0.04825
# [170]	validation_0-logloss:0.04819
# [171]	validation_0-logloss:0.04796
# [172]	validation_0-logloss:0.04798
# [173]	validation_0-logloss:0.04801
# [174]	validation_0-logloss:0.04806
# [175]	validation_0-logloss:0.04784
# [176]	validation_0-logloss:0.04776
# [177]	validation_0-logloss:0.04756
# [178]	validation_0-logloss:0.04750
# [179]	validation_0-logloss:0.04754
# [180]	validation_0-logloss:0.04732
# [181]	validation_0-logloss:0.04723
# [182]	validation_0-logloss:0.04728
# [183]	validation_0-logloss:0.04720
# [184]	validation_0-logloss:0.04719
# [185]	validation_0-logloss:0.04712
# [186]	validation_0-logloss:0.04703
# [187]	validation_0-logloss:0.04694
# [188]	validation_0-logloss:0.04678
# [189]	validation_0-logloss:0.04668
# [190]	validation_0-logloss:0.04658
# [191]	validation_0-logloss:0.04654
# [192]	validation_0-logloss:0.04649
# [193]	validation_0-logloss:0.04645
# [194]	validation_0-logloss:0.04634
# [195]	validation_0-logloss:0.04629
# [196]	validation_0-logloss:0.04637
# [197]	validation_0-logloss:0.04637
# [198]	validation_0-logloss:0.04630
# [199]	validation_0-logloss:0.04626
# [200]	validation_0-logloss:0.04615
# [201]	validation_0-logloss:0.04607
# [202]	validation_0-logloss:0.04605
# [203]	validation_0-logloss:0.04602
# [204]	validation_0-logloss:0.04602
# [205]	validation_0-logloss:0.04593
# [206]	validation_0-logloss:0.04592
# [207]	validation_0-logloss:0.04593
# [208]	validation_0-logloss:0.04582
# [209]	validation_0-logloss:0.04570
# [210]	validation_0-logloss:0.04573
# [211]	validation_0-logloss:0.04569
# [212]	validation_0-logloss:0.04563
# [213]	validation_0-logloss:0.04565
# [214]	validation_0-logloss:0.04559
# [215]	validation_0-logloss:0.04549
# [216]	validation_0-logloss:0.04551
# [217]	validation_0-logloss:0.04548
# [218]	validation_0-logloss:0.04547
# [219]	validation_0-logloss:0.04544
# [220]	validation_0-logloss:0.04532
# [221]	validation_0-logloss:0.04528
# [222]	validation_0-logloss:0.04527
# [223]	validation_0-logloss:0.04522
# [224]	validation_0-logloss:0.04517
# [225]	validation_0-logloss:0.04514
# [226]	validation_0-logloss:0.04512
# [227]	validation_0-logloss:0.04501
# [228]	validation_0-logloss:0.04503
# [229]	validation_0-logloss:0.04509
# [230]	validation_0-logloss:0.04507
# [231]	validation_0-logloss:0.04505
# [232]	validation_0-logloss:0.04499
# [233]	validation_0-logloss:0.04498
# [234]	validation_0-logloss:0.04490
# [235]	validation_0-logloss:0.04473
# [236]	validation_0-logloss:0.04475
# [237]	validation_0-logloss:0.04463
# [238]	validation_0-logloss:0.04465
# [239]	validation_0-logloss:0.04463
# [240]	validation_0-logloss:0.04460
# [241]	validation_0-logloss:0.04453
# [242]	validation_0-logloss:0.04447
# [243]	validation_0-logloss:0.04447
# [244]	validation_0-logloss:0.04433
# [245]	validation_0-logloss:0.04430
# [246]	validation_0-logloss:0.04430
# [247]	validation_0-logloss:0.04429
# [248]	validation_0-logloss:0.04428
# [249]	validation_0-logloss:0.04421
# [250]	validation_0-logloss:0.04415
# [251]	validation_0-logloss:0.04413
# [252]	validation_0-logloss:0.04411
# [253]	validation_0-logloss:0.04410
# [254]	validation_0-logloss:0.04403
# [255]	validation_0-logloss:0.04402
# [256]	validation_0-logloss:0.04407
# [257]	validation_0-logloss:0.04404
# [258]	validation_0-logloss:0.04396
# [259]	validation_0-logloss:0.04388
# [260]	validation_0-logloss:0.04389
# [261]	validation_0-logloss:0.04382
# [262]	validation_0-logloss:0.04381
# [263]	validation_0-logloss:0.04374
# [264]	validation_0-logloss:0.04373
# [265]	validation_0-logloss:0.04373
# [266]	validation_0-logloss:0.04379
# [267]	validation_0-logloss:0.04380
# [268]	validation_0-logloss:0.04372
# [269]	validation_0-logloss:0.04361
# [270]	validation_0-logloss:0.04356
# [271]	validation_0-logloss:0.04355
# [272]	validation_0-logloss:0.04355
# [273]	validation_0-logloss:0.04351
# [274]	validation_0-logloss:0.04349
# [275]	validation_0-logloss:0.04350
# [276]	validation_0-logloss:0.04347
# [277]	validation_0-logloss:0.04340
# [278]	validation_0-logloss:0.04344
# [279]	validation_0-logloss:0.04340
# [280]	validation_0-logloss:0.04340
# [281]	validation_0-logloss:0.04336
# [282]	validation_0-logloss:0.04336
# [283]	validation_0-logloss:0.04337
# [284]	validation_0-logloss:0.04337
# [285]	validation_0-logloss:0.04341
# [286]	validation_0-logloss:0.04338
# [287]	validation_0-logloss:0.04333
# [288]	validation_0-logloss:0.04330
# [289]	validation_0-logloss:0.04339
# [290]	validation_0-logloss:0.04335
# [291]	validation_0-logloss:0.04338
# [292]	validation_0-logloss:0.04333
# [293]	validation_0-logloss:0.04332
# [294]	validation_0-logloss:0.04332
# [295]	validation_0-logloss:0.04323
# [296]	validation_0-logloss:0.04325
# [297]	validation_0-logloss:0.04326
# [298]	validation_0-logloss:0.04328
# [299]	validation_0-logloss:0.04337
# [300]	validation_0-logloss:0.04333
# [301]	validation_0-logloss:0.04331
# [302]	validation_0-logloss:0.04324
# [303]	validation_0-logloss:0.04326
# [304]	validation_0-logloss:0.04321
# [305]	validation_0-logloss:0.04320
# [306]	validation_0-logloss:0.04315
# [307]	validation_0-logloss:0.04317
# [308]	validation_0-logloss:0.04317
# [309]	validation_0-logloss:0.04313
# [310]	validation_0-logloss:0.04305
# [311]	validation_0-logloss:0.04299
# [312]	validation_0-logloss:0.04298
# [313]	validation_0-logloss:0.04304
# [314]	validation_0-logloss:0.04298
# [315]	validation_0-logloss:0.04292
# [316]	validation_0-logloss:0.04291
# [317]	validation_0-logloss:0.04291
# [318]	validation_0-logloss:0.04289
# [319]	validation_0-logloss:0.04292
# [320]	validation_0-logloss:0.04282
# [321]	validation_0-logloss:0.04273
# [322]	validation_0-logloss:0.04269
# [323]	validation_0-logloss:0.04268
# [324]	validation_0-logloss:0.04265
# [325]	validation_0-logloss:0.04269
# [326]	validation_0-logloss:0.04275
# [327]	validation_0-logloss:0.04275
# [328]	validation_0-logloss:0.04270
# [329]	validation_0-logloss:0.04268
# [330]	validation_0-logloss:0.04266
# [331]	validation_0-logloss:0.04266
# [332]	validation_0-logloss:0.04264
# [333]	validation_0-logloss:0.04265
# [334]	validation_0-logloss:0.04272
# [335]	validation_0-logloss:0.04268
# [336]	validation_0-logloss:0.04268
# [337]	validation_0-logloss:0.04261
# [338]	validation_0-logloss:0.04260
# [339]	validation_0-logloss:0.04249
# [340]	validation_0-logloss:0.04249
# [341]	validation_0-logloss:0.04248
# [342]	validation_0-logloss:0.04250
# [343]	validation_0-logloss:0.04245
# [344]	validation_0-logloss:0.04252
# [345]	validation_0-logloss:0.04253
# [346]	validation_0-logloss:0.04255
# [347]	validation_0-logloss:0.04255
# [348]	validation_0-logloss:0.04267
# [349]	validation_0-logloss:0.04264
# [350]	validation_0-logloss:0.04269
# [351]	validation_0-logloss:0.04269
# [352]	validation_0-logloss:0.04261
# [353]	validation_0-logloss:0.04259
# [354]	validation_0-logloss:0.04261
# [355]	validation_0-logloss:0.04261
# [356]	validation_0-logloss:0.04261
# [357]	validation_0-logloss:0.04256
# [358]	validation_0-logloss:0.04251
# [359]	validation_0-logloss:0.04251
# [360]	validation_0-logloss:0.04251
# [361]	validation_0-logloss:0.04256
# [362]	validation_0-logloss:0.04260
# [363]	validation_0-logloss:0.04253
# [364]	validation_0-logloss:0.04253
# [365]	validation_0-logloss:0.04251
# [366]	validation_0-logloss:0.04251
# [367]	validation_0-logloss:0.04252
# [368]	validation_0-logloss:0.04251
# [369]	validation_0-logloss:0.04251
# [370]	validation_0-logloss:0.04245
# [371]	validation_0-logloss:0.04250
# [372]	validation_0-logloss:0.04251
# [373]	validation_0-logloss:0.04257
# [374]	validation_0-logloss:0.04253
# [375]	validation_0-logloss:0.04242
# [376]	validation_0-logloss:0.04242
# [377]	validation_0-logloss:0.04232
# [378]	validation_0-logloss:0.04235
# [379]	validation_0-logloss:0.04234
# [380]	validation_0-logloss:0.04234
# [381]	validation_0-logloss:0.04226
# [382]	validation_0-logloss:0.04230
# [383]	validation_0-logloss:0.04230
# [384]	validation_0-logloss:0.04230
# [385]	validation_0-logloss:0.04229
# [386]	validation_0-logloss:0.04236
# [387]	validation_0-logloss:0.04236
# [388]	validation_0-logloss:0.04234
# [389]	validation_0-logloss:0.04234
# [390]	validation_0-logloss:0.04234
# [391]	validation_0-logloss:0.04236
# [392]	validation_0-logloss:0.04236
# [393]	validation_0-logloss:0.04236
# [394]	validation_0-logloss:0.04243
# [395]	validation_0-logloss:0.04241
# [396]	validation_0-logloss:0.04228
# [397]	validation_0-logloss:0.04228
# [398]	validation_0-logloss:0.04224
# [399]	validation_0-logloss:0.04224
# [400]	validation_0-logloss:0.04230
# [401]	validation_0-logloss:0.04235
# [402]	validation_0-logloss:0.04226
# [403]	validation_0-logloss:0.04226
# [404]	validation_0-logloss:0.04226
# [405]	validation_0-logloss:0.04226
# [406]	validation_0-logloss:0.04226
# [407]	validation_0-logloss:0.04220
# [408]	validation_0-logloss:0.04221
# [409]	validation_0-logloss:0.04216
# [410]	validation_0-logloss:0.04211
# [411]	validation_0-logloss:0.04211
# [412]	validation_0-logloss:0.04211
# [413]	validation_0-logloss:0.04211
# [414]	validation_0-logloss:0.04211
# [415]	validation_0-logloss:0.04214
# [416]	validation_0-logloss:0.04221
# [417]	validation_0-logloss:0.04214
# [418]	validation_0-logloss:0.04217
# [419]	validation_0-logloss:0.04217
# [420]	validation_0-logloss:0.04207
# [421]	validation_0-logloss:0.04207
# [422]	validation_0-logloss:0.04210
# [423]	validation_0-logloss:0.04211
# [424]	validation_0-logloss:0.04211
# [425]	validation_0-logloss:0.04212
# [426]	validation_0-logloss:0.04212
# [427]	validation_0-logloss:0.04214
# [428]	validation_0-logloss:0.04211
# [429]	validation_0-logloss:0.04205
# [430]	validation_0-logloss:0.04207
# [431]	validation_0-logloss:0.04210
# [432]	validation_0-logloss:0.04210
# [433]	validation_0-logloss:0.04207
# [434]	validation_0-logloss:0.04204
# [435]	validation_0-logloss:0.04204
# [436]	validation_0-logloss:0.04204
# [437]	validation_0-logloss:0.04204
# [438]	validation_0-logloss:0.04204
# [439]	validation_0-logloss:0.04204
# [440]	validation_0-logloss:0.04199
# [441]	validation_0-logloss:0.04199
# [442]	validation_0-logloss:0.04204
# [443]	validation_0-logloss:0.04206
# [444]	validation_0-logloss:0.04211
# [445]	validation_0-logloss:0.04211
# [446]	validation_0-logloss:0.04211
# [447]	validation_0-logloss:0.04212
# [448]	validation_0-logloss:0.04218
# [449]	validation_0-logloss:0.04216
# [450]	validation_0-logloss:0.04216
# [451]	validation_0-logloss:0.04206
# [452]	validation_0-logloss:0.04206
# [453]	validation_0-logloss:0.04207
# [454]	validation_0-logloss:0.04206
# [455]	validation_0-logloss:0.04206
# [456]	validation_0-logloss:0.04206
# [457]	validation_0-logloss:0.04210
# [458]	validation_0-logloss:0.04210
# [459]	validation_0-logloss:0.04210
# [460]	validation_0-logloss:0.04210
# [461]	validation_0-logloss:0.04210
# [462]	validation_0-logloss:0.04205
# [463]	validation_0-logloss:0.04207
# [464]	validation_0-logloss:0.04207
# [465]	validation_0-logloss:0.04207
# [466]	validation_0-logloss:0.04207
# [467]	validation_0-logloss:0.04199
# [468]	validation_0-logloss:0.04199
# [469]	validation_0-logloss:0.04199
# [470]	validation_0-logloss:0.04199
# [471]	validation_0-logloss:0.04197
# [472]	validation_0-logloss:0.04192
# [473]	validation_0-logloss:0.04183
# [474]	validation_0-logloss:0.04183
# [475]	validation_0-logloss:0.04183
# [476]	validation_0-logloss:0.04183
# [477]	validation_0-logloss:0.04183
# [478]	validation_0-logloss:0.04183
# [479]	validation_0-logloss:0.04182
# [480]	validation_0-logloss:0.04178
# [481]	validation_0-logloss:0.04178
# [482]	validation_0-logloss:0.04177
# [483]	validation_0-logloss:0.04177
# [484]	validation_0-logloss:0.04180
# [485]	validation_0-logloss:0.04180
# [486]	validation_0-logloss:0.04180
# [487]	validation_0-logloss:0.04180
# [488]	validation_0-logloss:0.04180
# [489]	validation_0-logloss:0.04180
# [490]	validation_0-logloss:0.04173
# [491]	validation_0-logloss:0.04177
# [492]	validation_0-logloss:0.04171
# [493]	validation_0-logloss:0.04173
# [494]	validation_0-logloss:0.04173
# [495]	validation_0-logloss:0.04173
# [496]	validation_0-logloss:0.04172
# [497]	validation_0-logloss:0.04175
# [498]	validation_0-logloss:0.04175
# [499]	validation_0-logloss:0.04175
# [500]	validation_0-logloss:0.04175
# [501]	validation_0-logloss:0.04175
# [502]	validation_0-logloss:0.04175
# [503]	validation_0-logloss:0.04177
# [504]	validation_0-logloss:0.04174
# [505]	validation_0-logloss:0.04174
# [506]	validation_0-logloss:0.04177
# [507]	validation_0-logloss:0.04181
# [508]	validation_0-logloss:0.04181
# [509]	validation_0-logloss:0.04177
# [510]	validation_0-logloss:0.04174
# [511]	validation_0-logloss:0.04174
# [512]	validation_0-logloss:0.04174
# [513]	validation_0-logloss:0.04174
# [514]	validation_0-logloss:0.04174
# [515]	validation_0-logloss:0.04167
# [516]	validation_0-logloss:0.04167
# [517]	validation_0-logloss:0.04167
# [518]	validation_0-logloss:0.04167
# [519]	validation_0-logloss:0.04164
# [520]	validation_0-logloss:0.04156
# [521]	validation_0-logloss:0.04156
# [522]	validation_0-logloss:0.04156
# [523]	validation_0-logloss:0.04156
# [524]	validation_0-logloss:0.04156
# [525]	validation_0-logloss:0.04158
# [526]	validation_0-logloss:0.04158
# [527]	validation_0-logloss:0.04158
# [528]	validation_0-logloss:0.04158
# [529]	validation_0-logloss:0.04158
# [530]	validation_0-logloss:0.04155
# [531]	validation_0-logloss:0.04155
# [532]	validation_0-logloss:0.04155
# [533]	validation_0-logloss:0.04155
# [534]	validation_0-logloss:0.04155
# [535]	validation_0-logloss:0.04155
# [536]	validation_0-logloss:0.04155
# [537]	validation_0-logloss:0.04156
# [538]	validation_0-logloss:0.04156
# [539]	validation_0-logloss:0.04156
# [540]	validation_0-logloss:0.04156
# [541]	validation_0-logloss:0.04152
# [542]	validation_0-logloss:0.04156
# [543]	validation_0-logloss:0.04156
# [544]	validation_0-logloss:0.04156
# [545]	validation_0-logloss:0.04156
# [546]	validation_0-logloss:0.04156
# [547]	validation_0-logloss:0.04161
# [548]	validation_0-logloss:0.04161
# [549]	validation_0-logloss:0.04161
# [550]	validation_0-logloss:0.04161
# [551]	validation_0-logloss:0.04161
# [552]	validation_0-logloss:0.04161
# [553]	validation_0-logloss:0.04161
# [554]	validation_0-logloss:0.04161
# [555]	validation_0-logloss:0.04161
# [556]	validation_0-logloss:0.04157
# [557]	validation_0-logloss:0.04157
# [558]	validation_0-logloss:0.04157
# [559]	validation_0-logloss:0.04157
# [560]	validation_0-logloss:0.04154
# [561]	validation_0-logloss:0.04152
# [562]	validation_0-logloss:0.04152
# [563]	validation_0-logloss:0.04152
# [564]	validation_0-logloss:0.04154
# [565]	validation_0-logloss:0.04151
# [566]	validation_0-logloss:0.04151
# [567]	validation_0-logloss:0.04151
# [568]	validation_0-logloss:0.04151
# [569]	validation_0-logloss:0.04151
# [570]	validation_0-logloss:0.04151
# [571]	validation_0-logloss:0.04151
# [572]	validation_0-logloss:0.04151
# [573]	validation_0-logloss:0.04151
# [574]	validation_0-logloss:0.04151
# [575]	validation_0-logloss:0.04151
# [576]	validation_0-logloss:0.04150
# [577]	validation_0-logloss:0.04150
# [578]	validation_0-logloss:0.04139
# [579]	validation_0-logloss:0.04139
# [580]	validation_0-logloss:0.04139
# [581]	validation_0-logloss:0.04135
# [582]	validation_0-logloss:0.04137
# [583]	validation_0-logloss:0.04137
# [584]	validation_0-logloss:0.04137
# [585]	validation_0-logloss:0.04137
# [586]	validation_0-logloss:0.04136
# [587]	validation_0-logloss:0.04136
# [588]	validation_0-logloss:0.04136
# [589]	validation_0-logloss:0.04136
# [590]	validation_0-logloss:0.04136
# [591]	validation_0-logloss:0.04136
# [592]	validation_0-logloss:0.04131
# [593]	validation_0-logloss:0.04131
# [594]	validation_0-logloss:0.04131
# [595]	validation_0-logloss:0.04131
# [596]	validation_0-logloss:0.04131
# [597]	validation_0-logloss:0.04131
# [598]	validation_0-logloss:0.04130
# [599]	validation_0-logloss:0.04132
# [600]	validation_0-logloss:0.04132
# [601]	validation_0-logloss:0.04132
# [602]	validation_0-logloss:0.04131
# [603]	validation_0-logloss:0.04131
# [604]	validation_0-logloss:0.04135
# [605]	validation_0-logloss:0.04135
# [606]	validation_0-logloss:0.04135
# [607]	validation_0-logloss:0.04135
# [608]	validation_0-logloss:0.04135
# [609]	validation_0-logloss:0.04128
# [610]	validation_0-logloss:0.04128
# [611]	validation_0-logloss:0.04128
# [612]	validation_0-logloss:0.04128
# [613]	validation_0-logloss:0.04128
# [614]	validation_0-logloss:0.04128
# [615]	validation_0-logloss:0.04128
# [616]	validation_0-logloss:0.04128
# [617]	validation_0-logloss:0.04135
# [618]	validation_0-logloss:0.04137
# [619]	validation_0-logloss:0.04137
# [620]	validation_0-logloss:0.04137
# [621]	validation_0-logloss:0.04137
# [622]	validation_0-logloss:0.04137
# [623]	validation_0-logloss:0.04132
# [624]	validation_0-logloss:0.04132
# [625]	validation_0-logloss:0.04132
# [626]	validation_0-logloss:0.04134
# [627]	validation_0-logloss:0.04134
# [628]	validation_0-logloss:0.04134
# [629]	validation_0-logloss:0.04139
# [630]	validation_0-logloss:0.04138
# [631]	validation_0-logloss:0.04138
# [632]	validation_0-logloss:0.04138
# [633]	validation_0-logloss:0.04138
# [634]	validation_0-logloss:0.04141
# [635]	validation_0-logloss:0.04141
# [636]	validation_0-logloss:0.04141
# [637]	validation_0-logloss:0.04141
# [638]	validation_0-logloss:0.04141
# [639]	validation_0-logloss:0.04141
# [640]	validation_0-logloss:0.04140
# [641]	validation_0-logloss:0.04140
# [642]	validation_0-logloss:0.04137
# [643]	validation_0-logloss:0.04137
# [644]	validation_0-logloss:0.04137
# [645]	validation_0-logloss:0.04137
# [646]	validation_0-logloss:0.04139
# [647]	validation_0-logloss:0.04139
# [648]	validation_0-logloss:0.04139
# [649]	validation_0-logloss:0.04139
# [650]	validation_0-logloss:0.04129
# [651]	validation_0-logloss:0.04129
# [652]	validation_0-logloss:0.04129
# [653]	validation_0-logloss:0.04129
# [654]	validation_0-logloss:0.04129
# [655]	validation_0-logloss:0.04129
# [656]	validation_0-logloss:0.04129
# [657]	validation_0-logloss:0.04129
# [658]	validation_0-logloss:0.04129
# [659]	validation_0-logloss:0.04129
# [660]	validation_0-logloss:0.04129
# [661]	validation_0-logloss:0.04129
# [662]	validation_0-logloss:0.04129
# [663]	validation_0-logloss:0.04127
# [664]	validation_0-logloss:0.04127
# [665]	validation_0-logloss:0.04127
# [666]	validation_0-logloss:0.04133
# [667]	validation_0-logloss:0.04133
# [668]	validation_0-logloss:0.04133
# [669]	validation_0-logloss:0.04133
# [670]	validation_0-logloss:0.04133
# [671]	validation_0-logloss:0.04133
# [672]	validation_0-logloss:0.04125
# [673]	validation_0-logloss:0.04125
# [674]	validation_0-logloss:0.04125
# [675]	validation_0-logloss:0.04125
# [676]	validation_0-logloss:0.04125
# [677]	validation_0-logloss:0.04125
# [678]	validation_0-logloss:0.04127
# [679]	validation_0-logloss:0.04127
# [680]	validation_0-logloss:0.04127
# [681]	validation_0-logloss:0.04125
# [682]	validation_0-logloss:0.04120
# [683]	validation_0-logloss:0.04120
# [684]	validation_0-logloss:0.04120
# [685]	validation_0-logloss:0.04120
# [686]	validation_0-logloss:0.04122
# [687]	validation_0-logloss:0.04122
# [688]	validation_0-logloss:0.04122
# [689]	validation_0-logloss:0.04126
# [690]	validation_0-logloss:0.04126
# [691]	validation_0-logloss:0.04134
# [692]	validation_0-logloss:0.04134
# [693]	validation_0-logloss:0.04134
# [694]	validation_0-logloss:0.04134
# [695]	validation_0-logloss:0.04132
# [696]	validation_0-logloss:0.04132
# [697]	validation_0-logloss:0.04132
# [698]	validation_0-logloss:0.04132
# [699]	validation_0-logloss:0.04132
# [700]	validation_0-logloss:0.04132
# [701]	validation_0-logloss:0.04135
# [702]	validation_0-logloss:0.04135
# [703]	validation_0-logloss:0.04135
# [704]	validation_0-logloss:0.04142
# [705]	validation_0-logloss:0.04147
# [706]	validation_0-logloss:0.04145
# [707]	validation_0-logloss:0.04145
# [708]	validation_0-logloss:0.04145
# [709]	validation_0-logloss:0.04145
# [710]	validation_0-logloss:0.04145
# [711]	validation_0-logloss:0.04144
# [712]	validation_0-logloss:0.04137
# [713]	validation_0-logloss:0.04137
# [714]	validation_0-logloss:0.04136
# [715]	validation_0-logloss:0.04136
# [716]	validation_0-logloss:0.04133
# [717]	validation_0-logloss:0.04132
# [718]	validation_0-logloss:0.04132
# [719]	validation_0-logloss:0.04132
# [720]	validation_0-logloss:0.04132
# [721]	validation_0-logloss:0.04132
# [722]	validation_0-logloss:0.04132
# [723]	validation_0-logloss:0.04133
# [724]	validation_0-logloss:0.04133
# [725]	validation_0-logloss:0.04127
# [726]	validation_0-logloss:0.04127
# [727]	validation_0-logloss:0.04127
# [728]	validation_0-logloss:0.04124
# [729]	validation_0-logloss:0.04124
# [730]	validation_0-logloss:0.04124
# [731]	validation_0-logloss:0.04124
# [732]	validation_0-logloss:0.04124
# [733]	validation_0-logloss:0.04124
# [734]	validation_0-logloss:0.04124
# [735]	validation_0-logloss:0.04124
# [736]	validation_0-logloss:0.04124
# [737]	validation_0-logloss:0.04124
# [738]	validation_0-logloss:0.04124
# [739]	validation_0-logloss:0.04124
# [740]	validation_0-logloss:0.04124
# [741]	validation_0-logloss:0.04124
# [742]	validation_0-logloss:0.04124
# [743]	validation_0-logloss:0.04124
# [744]	validation_0-logloss:0.04124
# [745]	validation_0-logloss:0.04124
# [746]	validation_0-logloss:0.04117
# [747]	validation_0-logloss:0.04117
# [748]	validation_0-logloss:0.04117
# [749]	validation_0-logloss:0.04117
# [750]	validation_0-logloss:0.04117
# [751]	validation_0-logloss:0.04117
# [752]	validation_0-logloss:0.04117
# [753]	validation_0-logloss:0.04117
# [754]	validation_0-logloss:0.04117
# [755]	validation_0-logloss:0.04117
# [756]	validation_0-logloss:0.04117
# [757]	validation_0-logloss:0.04117
# [758]	validation_0-logloss:0.04117
# [759]	validation_0-logloss:0.04119
# [760]	validation_0-logloss:0.04119
# [761]	validation_0-logloss:0.04119
# [762]	validation_0-logloss:0.04119
# [763]	validation_0-logloss:0.04119
# [764]	validation_0-logloss:0.04119
# [765]	validation_0-logloss:0.04119
# [766]	validation_0-logloss:0.04118
# [767]	validation_0-logloss:0.04118
# [768]	validation_0-logloss:0.04118
# [769]	validation_0-logloss:0.04118
# [770]	validation_0-logloss:0.04118
# [771]	validation_0-logloss:0.04118
# [772]	validation_0-logloss:0.04118
# [773]	validation_0-logloss:0.04118
# [774]	validation_0-logloss:0.04118
# [775]	validation_0-logloss:0.04118
# [776]	validation_0-logloss:0.04118
# [777]	validation_0-logloss:0.04111
# [778]	validation_0-logloss:0.04111
# [779]	validation_0-logloss:0.04111
# [780]	validation_0-logloss:0.04111
# [781]	validation_0-logloss:0.04111
# [782]	validation_0-logloss:0.04113
# [783]	validation_0-logloss:0.04113
# [784]	validation_0-logloss:0.04116
# [785]	validation_0-logloss:0.04119
# [786]	validation_0-logloss:0.04119
# [787]	validation_0-logloss:0.04109
# [788]	validation_0-logloss:0.04109
# [789]	validation_0-logloss:0.04109
# [790]	validation_0-logloss:0.04109
# [791]	validation_0-logloss:0.04107
# [792]	validation_0-logloss:0.04107
# [793]	validation_0-logloss:0.04107
# [794]	validation_0-logloss:0.04107
# [795]	validation_0-logloss:0.04107
# [796]	validation_0-logloss:0.04107
# [797]	validation_0-logloss:0.04107
# [798]	validation_0-logloss:0.04107
# [799]	validation_0-logloss:0.04107
# [800]	validation_0-logloss:0.04107
# [801]	validation_0-logloss:0.04107
# [802]	validation_0-logloss:0.04107
# [803]	validation_0-logloss:0.04107
# [804]	validation_0-logloss:0.04109
# [805]	validation_0-logloss:0.04109
# [806]	validation_0-logloss:0.04109
# [807]	validation_0-logloss:0.04109
# [808]	validation_0-logloss:0.04106
# [809]	validation_0-logloss:0.04106
# [810]	validation_0-logloss:0.04106
# [811]	validation_0-logloss:0.04106
# [812]	validation_0-logloss:0.04108
# [813]	validation_0-logloss:0.04108
# [814]	validation_0-logloss:0.04108
# [815]	validation_0-logloss:0.04108
# [816]	validation_0-logloss:0.04108
# [817]	validation_0-logloss:0.04108
# [818]	validation_0-logloss:0.04108
# [819]	validation_0-logloss:0.04106
# [820]	validation_0-logloss:0.04106
# [821]	validation_0-logloss:0.04106
# [822]	validation_0-logloss:0.04102
# [823]	validation_0-logloss:0.04102
# [824]	validation_0-logloss:0.04102
# [825]	validation_0-logloss:0.04102
# [826]	validation_0-logloss:0.04102
# [827]	validation_0-logloss:0.04102
# [828]	validation_0-logloss:0.04102
# [829]	validation_0-logloss:0.04102
# [830]	validation_0-logloss:0.04102
# [831]	validation_0-logloss:0.04102
# [832]	validation_0-logloss:0.04102
# [833]	validation_0-logloss:0.04102
# [834]	validation_0-logloss:0.04094
# [835]	validation_0-logloss:0.04094
# [836]	validation_0-logloss:0.04094
# [837]	validation_0-logloss:0.04097
# [838]	validation_0-logloss:0.04097
# [839]	validation_0-logloss:0.04097
# [840]	validation_0-logloss:0.04097
# [841]	validation_0-logloss:0.04090
# [842]	validation_0-logloss:0.04090
# [843]	validation_0-logloss:0.04090
# [844]	validation_0-logloss:0.04091
# [845]	validation_0-logloss:0.04091
# [846]	validation_0-logloss:0.04091
# [847]	validation_0-logloss:0.04094
# [848]	validation_0-logloss:0.04094
# [849]	validation_0-logloss:0.04094
# [850]	validation_0-logloss:0.04094
# [851]	validation_0-logloss:0.04094
# [852]	validation_0-logloss:0.04094
# [853]	validation_0-logloss:0.04094
# [854]	validation_0-logloss:0.04094
# [855]	validation_0-logloss:0.04094
# [856]	validation_0-logloss:0.04097
# [857]	validation_0-logloss:0.04097
# [858]	validation_0-logloss:0.04097
# [859]	validation_0-logloss:0.04096
# [860]	validation_0-logloss:0.04101
# [861]	validation_0-logloss:0.04101
# [862]	validation_0-logloss:0.04101
# [863]	validation_0-logloss:0.04101
# [864]	validation_0-logloss:0.04101
# [865]	validation_0-logloss:0.04101
# [866]	validation_0-logloss:0.04101
# [867]	validation_0-logloss:0.04101
# [868]	validation_0-logloss:0.04101
# [869]	validation_0-logloss:0.04101
# [870]	validation_0-logloss:0.04101
# [871]	validation_0-logloss:0.04101
# [872]	validation_0-logloss:0.04101
# [873]	validation_0-logloss:0.04101
# [874]	validation_0-logloss:0.04101
# [875]	validation_0-logloss:0.04101
# [876]	validation_0-logloss:0.04097
# [877]	validation_0-logloss:0.04097
# [878]	validation_0-logloss:0.04097
# [879]	validation_0-logloss:0.04088
# [880]	validation_0-logloss:0.04088
# [881]	validation_0-logloss:0.04088
# [882]	validation_0-logloss:0.04088
# [883]	validation_0-logloss:0.04088
# [884]	validation_0-logloss:0.04088
# [885]	validation_0-logloss:0.04088
# [886]	validation_0-logloss:0.04088
# [887]	validation_0-logloss:0.04088
# [888]	validation_0-logloss:0.04088
# [889]	validation_0-logloss:0.04088
# [890]	validation_0-logloss:0.04088
# [891]	validation_0-logloss:0.04088
# [892]	validation_0-logloss:0.04088
# [893]	validation_0-logloss:0.04088
# [894]	validation_0-logloss:0.04088
# [895]	validation_0-logloss:0.04088
# [896]	validation_0-logloss:0.04088
# [897]	validation_0-logloss:0.04088
# [898]	validation_0-logloss:0.04088
# [899]	validation_0-logloss:0.04088
# [900]	validation_0-logloss:0.04088
# [901]	validation_0-logloss:0.04088
# [902]	validation_0-logloss:0.04088
# [903]	validation_0-logloss:0.04088
# [904]	validation_0-logloss:0.04088
# [905]	validation_0-logloss:0.04088
# [906]	validation_0-logloss:0.04088
# [907]	validation_0-logloss:0.04088
# [908]	validation_0-logloss:0.04088
# [909]	validation_0-logloss:0.04088
# [910]	validation_0-logloss:0.04088
# [911]	validation_0-logloss:0.04087
# [912]	validation_0-logloss:0.04087
# [913]	validation_0-logloss:0.04087
# [914]	validation_0-logloss:0.04087
# [915]	validation_0-logloss:0.04087
# [916]	validation_0-logloss:0.04087
# [917]	validation_0-logloss:0.04087
# [918]	validation_0-logloss:0.04087
# [919]	validation_0-logloss:0.04087
# [920]	validation_0-logloss:0.04087
# [921]	validation_0-logloss:0.04087
# [922]	validation_0-logloss:0.04087
# [923]	validation_0-logloss:0.04087
# [924]	validation_0-logloss:0.04087
# [925]	validation_0-logloss:0.04087
# [926]	validation_0-logloss:0.04087
# [927]	validation_0-logloss:0.04087
# [928]	validation_0-logloss:0.04087
# [929]	validation_0-logloss:0.04087
# [930]	validation_0-logloss:0.04087
# [931]	validation_0-logloss:0.04087
# [932]	validation_0-logloss:0.04087
# [933]	validation_0-logloss:0.04087
# [934]	validation_0-logloss:0.04087
# [935]	validation_0-logloss:0.04090
# [936]	validation_0-logloss:0.04090
# [937]	validation_0-logloss:0.04090
# [938]	validation_0-logloss:0.04089
# [939]	validation_0-logloss:0.04089
# [940]	validation_0-logloss:0.04089
# [941]	validation_0-logloss:0.04089
# [942]	validation_0-logloss:0.04089
# [943]	validation_0-logloss:0.04089
# [944]	validation_0-logloss:0.04089
# [945]	validation_0-logloss:0.04089
# [946]	validation_0-logloss:0.04089
# [947]	validation_0-logloss:0.04095
# [948]	validation_0-logloss:0.04096
# [949]	validation_0-logloss:0.04096
# [950]	validation_0-logloss:0.04096
# [951]	validation_0-logloss:0.04096
# [952]	validation_0-logloss:0.04096
# [953]	validation_0-logloss:0.04096
# [954]	validation_0-logloss:0.04093
# [955]	validation_0-logloss:0.04093
# [956]	validation_0-logloss:0.04095
# [957]	validation_0-logloss:0.04095
# [958]	validation_0-logloss:0.04095
# [959]	validation_0-logloss:0.04095
# [960]	validation_0-logloss:0.04095
# [961]	validation_0-logloss:0.04095
# [962]	validation_0-logloss:0.04095
# [963]	validation_0-logloss:0.04095
# [964]	validation_0-logloss:0.04095
# [965]	validation_0-logloss:0.04095
# [966]	validation_0-logloss:0.04095
# [967]	validation_0-logloss:0.04095
# [968]	validation_0-logloss:0.04086
# [969]	validation_0-logloss:0.04086
# [970]	validation_0-logloss:0.04086
# [971]	validation_0-logloss:0.04086
# [972]	validation_0-logloss:0.04086
# [973]	validation_0-logloss:0.04086
# [974]	validation_0-logloss:0.04086
# [975]	validation_0-logloss:0.04086
# [976]	validation_0-logloss:0.04086
# [977]	validation_0-logloss:0.04086
# [978]	validation_0-logloss:0.04086
# [979]	validation_0-logloss:0.04086
# [980]	validation_0-logloss:0.04086
# [981]	validation_0-logloss:0.04086
# [982]	validation_0-logloss:0.04086
# [983]	validation_0-logloss:0.04086
# [984]	validation_0-logloss:0.04087
# [985]	validation_0-logloss:0.04086
# [986]	validation_0-logloss:0.04086
# [987]	validation_0-logloss:0.04081
# [988]	validation_0-logloss:0.04081
# [989]	validation_0-logloss:0.04081
# [990]	validation_0-logloss:0.04081
# [991]	validation_0-logloss:0.04084
# [992]	validation_0-logloss:0.04084
# [993]	validation_0-logloss:0.04084
# [994]	validation_0-logloss:0.04084
# [995]	validation_0-logloss:0.04088
# [996]	validation_0-logloss:0.04090
# [997]	validation_0-logloss:0.04090
# [998]	validation_0-logloss:0.04090
# [999]	validation_0-logloss:0.04090
# Fold0 AUC = 0.995706
# [0]	validation_0-logloss:0.42511
# [1]	validation_0-logloss:0.40224
# [2]	validation_0-logloss:0.37839
# [3]	validation_0-logloss:0.36006
# [4]	validation_0-logloss:0.33997
# [5]	validation_0-logloss:0.32532
# [6]	validation_0-logloss:0.31134
# [7]	validation_0-logloss:0.29758
# [8]	validation_0-logloss:0.28425
# [9]	validation_0-logloss:0.27293
# [10]	validation_0-logloss:0.26317
# [11]	validation_0-logloss:0.25262
# [12]	validation_0-logloss:0.24477
# [13]	validation_0-logloss:0.23607
# [14]	validation_0-logloss:0.22683
# [15]	validation_0-logloss:0.21905
# [16]	validation_0-logloss:0.21197
# [17]	validation_0-logloss:0.20496
# [18]	validation_0-logloss:0.19997
# [19]	validation_0-logloss:0.19508
# [20]	validation_0-logloss:0.19050
# [21]	validation_0-logloss:0.18511
# [22]	validation_0-logloss:0.18010
# [23]	validation_0-logloss:0.17554
# [24]	validation_0-logloss:0.17063
# [25]	validation_0-logloss:0.16662
# [26]	validation_0-logloss:0.16244
# [27]	validation_0-logloss:0.15830
# [28]	validation_0-logloss:0.15468
# [29]	validation_0-logloss:0.15137
# [30]	validation_0-logloss:0.14891
# [31]	validation_0-logloss:0.14528
# [32]	validation_0-logloss:0.14251
# [33]	validation_0-logloss:0.13956
# [34]	validation_0-logloss:0.13730
# [35]	validation_0-logloss:0.13494
# [36]	validation_0-logloss:0.13272
# [37]	validation_0-logloss:0.12999
# [38]	validation_0-logloss:0.12779
# [39]	validation_0-logloss:0.12529
# [40]	validation_0-logloss:0.12323
# [41]	validation_0-logloss:0.12172
# [42]	validation_0-logloss:0.12009
# [43]	validation_0-logloss:0.11846
# [44]	validation_0-logloss:0.11714
# [45]	validation_0-logloss:0.11580
# [46]	validation_0-logloss:0.11451
# [47]	validation_0-logloss:0.11267
# [48]	validation_0-logloss:0.11106
# [49]	validation_0-logloss:0.10999
# [50]	validation_0-logloss:0.10859
# [51]	validation_0-logloss:0.10735
# [52]	validation_0-logloss:0.10630
# [53]	validation_0-logloss:0.10473
# [54]	validation_0-logloss:0.10371
# [55]	validation_0-logloss:0.10246
# [56]	validation_0-logloss:0.10157
# [57]	validation_0-logloss:0.10035
# [58]	validation_0-logloss:0.09929
# [59]	validation_0-logloss:0.09848
# [60]	validation_0-logloss:0.09762
# [61]	validation_0-logloss:0.09730
# [62]	validation_0-logloss:0.09655
# [63]	validation_0-logloss:0.09606
# [64]	validation_0-logloss:0.09541
# [65]	validation_0-logloss:0.09504
# [66]	validation_0-logloss:0.09451
# [67]	validation_0-logloss:0.09446
# [68]	validation_0-logloss:0.09385
# [69]	validation_0-logloss:0.09327
# [70]	validation_0-logloss:0.09280
# [71]	validation_0-logloss:0.09224
# [72]	validation_0-logloss:0.09167
# [73]	validation_0-logloss:0.09117
# [74]	validation_0-logloss:0.09067
# [75]	validation_0-logloss:0.09033
# [76]	validation_0-logloss:0.08976
# [77]	validation_0-logloss:0.08930
# [78]	validation_0-logloss:0.08876
# [79]	validation_0-logloss:0.08843
# [80]	validation_0-logloss:0.08791
# [81]	validation_0-logloss:0.08751
# [82]	validation_0-logloss:0.08718
# [83]	validation_0-logloss:0.08672
# [84]	validation_0-logloss:0.08642
# [85]	validation_0-logloss:0.08605
# [86]	validation_0-logloss:0.08591
# [87]	validation_0-logloss:0.08555
# [88]	validation_0-logloss:0.08521
# [89]	validation_0-logloss:0.08491
# [90]	validation_0-logloss:0.08490
# [91]	validation_0-logloss:0.08435
# [92]	validation_0-logloss:0.08407
# [93]	validation_0-logloss:0.08407
# [94]	validation_0-logloss:0.08384
# [95]	validation_0-logloss:0.08385
# [96]	validation_0-logloss:0.08359
# [97]	validation_0-logloss:0.08309
# [98]	validation_0-logloss:0.08244
# [99]	validation_0-logloss:0.08252
# [100]	validation_0-logloss:0.08240
# [101]	validation_0-logloss:0.08184
# [102]	validation_0-logloss:0.08166
# [103]	validation_0-logloss:0.08160
# [104]	validation_0-logloss:0.08129
# [105]	validation_0-logloss:0.08130
# [106]	validation_0-logloss:0.08113
# [107]	validation_0-logloss:0.08075
# [108]	validation_0-logloss:0.08047
# [109]	validation_0-logloss:0.08034
# [110]	validation_0-logloss:0.08025
# [111]	validation_0-logloss:0.07967
# [112]	validation_0-logloss:0.07956
# [113]	validation_0-logloss:0.07936
# [114]	validation_0-logloss:0.07910
# [115]	validation_0-logloss:0.07897
# [116]	validation_0-logloss:0.07877
# [117]	validation_0-logloss:0.07828
# [118]	validation_0-logloss:0.07841
# [119]	validation_0-logloss:0.07841
# [120]	validation_0-logloss:0.07836
# [121]	validation_0-logloss:0.07793
# [122]	validation_0-logloss:0.07789
# [123]	validation_0-logloss:0.07763
# [124]	validation_0-logloss:0.07742
# [125]	validation_0-logloss:0.07726
# [126]	validation_0-logloss:0.07727
# [127]	validation_0-logloss:0.07732
# [128]	validation_0-logloss:0.07717
# [129]	validation_0-logloss:0.07687
# [130]	validation_0-logloss:0.07671
# [131]	validation_0-logloss:0.07660
# [132]	validation_0-logloss:0.07672
# [133]	validation_0-logloss:0.07658
# [134]	validation_0-logloss:0.07647
# [135]	validation_0-logloss:0.07663
# [136]	validation_0-logloss:0.07641
# [137]	validation_0-logloss:0.07644
# [138]	validation_0-logloss:0.07638
# [139]	validation_0-logloss:0.07638
# [140]	validation_0-logloss:0.07642
# [141]	validation_0-logloss:0.07620
# [142]	validation_0-logloss:0.07618
# [143]	validation_0-logloss:0.07601
# [144]	validation_0-logloss:0.07567
# [145]	validation_0-logloss:0.07549
# [146]	validation_0-logloss:0.07546
# [147]	validation_0-logloss:0.07544
# [148]	validation_0-logloss:0.07528
# [149]	validation_0-logloss:0.07524
# [150]	validation_0-logloss:0.07522
# [151]	validation_0-logloss:0.07490
# [152]	validation_0-logloss:0.07460
# [153]	validation_0-logloss:0.07448
# [154]	validation_0-logloss:0.07453
# [155]	validation_0-logloss:0.07471
# [156]	validation_0-logloss:0.07474
# [157]	validation_0-logloss:0.07453
# [158]	validation_0-logloss:0.07436
# [159]	validation_0-logloss:0.07426
# [160]	validation_0-logloss:0.07413
# [161]	validation_0-logloss:0.07400
# [162]	validation_0-logloss:0.07398
# [163]	validation_0-logloss:0.07403
# [164]	validation_0-logloss:0.07399
# [165]	validation_0-logloss:0.07379
# [166]	validation_0-logloss:0.07387
# [167]	validation_0-logloss:0.07389
# [168]	validation_0-logloss:0.07384
# [169]	validation_0-logloss:0.07385
# [170]	validation_0-logloss:0.07385
# [171]	validation_0-logloss:0.07364
# [172]	validation_0-logloss:0.07353
# [173]	validation_0-logloss:0.07352
# [174]	validation_0-logloss:0.07353
# [175]	validation_0-logloss:0.07319
# [176]	validation_0-logloss:0.07295
# [177]	validation_0-logloss:0.07292
# [178]	validation_0-logloss:0.07278
# [179]	validation_0-logloss:0.07271
# [180]	validation_0-logloss:0.07258
# [181]	validation_0-logloss:0.07242
# [182]	validation_0-logloss:0.07232
# [183]	validation_0-logloss:0.07235
# [184]	validation_0-logloss:0.07233
# [185]	validation_0-logloss:0.07205
# [186]	validation_0-logloss:0.07191
# [187]	validation_0-logloss:0.07187
# [188]	validation_0-logloss:0.07173
# [189]	validation_0-logloss:0.07152
# [190]	validation_0-logloss:0.07153
# [191]	validation_0-logloss:0.07137
# [192]	validation_0-logloss:0.07112
# [193]	validation_0-logloss:0.07095
# [194]	validation_0-logloss:0.07077
# [195]	validation_0-logloss:0.07085
# [196]	validation_0-logloss:0.07092
# [197]	validation_0-logloss:0.07091
# [198]	validation_0-logloss:0.07087
# [199]	validation_0-logloss:0.07087
# [200]	validation_0-logloss:0.07069
# [201]	validation_0-logloss:0.07071
# [202]	validation_0-logloss:0.07061
# [203]	validation_0-logloss:0.07064
# [204]	validation_0-logloss:0.07079
# [205]	validation_0-logloss:0.07066
# [206]	validation_0-logloss:0.07062
# [207]	validation_0-logloss:0.07051
# [208]	validation_0-logloss:0.07052
# [209]	validation_0-logloss:0.07046
# [210]	validation_0-logloss:0.07038
# [211]	validation_0-logloss:0.07038
# [212]	validation_0-logloss:0.07020
# [213]	validation_0-logloss:0.07027
# [214]	validation_0-logloss:0.07015
# [215]	validation_0-logloss:0.07009
# [216]	validation_0-logloss:0.06989
# [217]	validation_0-logloss:0.06993
# [218]	validation_0-logloss:0.06978
# [219]	validation_0-logloss:0.06979
# [220]	validation_0-logloss:0.06971
# [221]	validation_0-logloss:0.06958
# [222]	validation_0-logloss:0.06946
# [223]	validation_0-logloss:0.06938
# [224]	validation_0-logloss:0.06932
# [225]	validation_0-logloss:0.06934
# [226]	validation_0-logloss:0.06926
# [227]	validation_0-logloss:0.06920
# [228]	validation_0-logloss:0.06911
# [229]	validation_0-logloss:0.06907
# [230]	validation_0-logloss:0.06911
# [231]	validation_0-logloss:0.06918
# [232]	validation_0-logloss:0.06909
# [233]	validation_0-logloss:0.06907
# [234]	validation_0-logloss:0.06907
# [235]	validation_0-logloss:0.06905
# [236]	validation_0-logloss:0.06903
# [237]	validation_0-logloss:0.06898
# [238]	validation_0-logloss:0.06889
# [239]	validation_0-logloss:0.06894
# [240]	validation_0-logloss:0.06899
# [241]	validation_0-logloss:0.06891
# [242]	validation_0-logloss:0.06875
# [243]	validation_0-logloss:0.06869
# [244]	validation_0-logloss:0.06879
# [245]	validation_0-logloss:0.06876
# [246]	validation_0-logloss:0.06865
# [247]	validation_0-logloss:0.06863
# [248]	validation_0-logloss:0.06852
# [249]	validation_0-logloss:0.06852
# [250]	validation_0-logloss:0.06844
# [251]	validation_0-logloss:0.06842
# [252]	validation_0-logloss:0.06850
# [253]	validation_0-logloss:0.06831
# [254]	validation_0-logloss:0.06833
# [255]	validation_0-logloss:0.06831
# [256]	validation_0-logloss:0.06821
# [257]	validation_0-logloss:0.06819
# [258]	validation_0-logloss:0.06819
# [259]	validation_0-logloss:0.06831
# [260]	validation_0-logloss:0.06836
# [261]	validation_0-logloss:0.06840
# [262]	validation_0-logloss:0.06833
# [263]	validation_0-logloss:0.06815
# [264]	validation_0-logloss:0.06819
# [265]	validation_0-logloss:0.06819
# [266]	validation_0-logloss:0.06819
# [267]	validation_0-logloss:0.06807
# [268]	validation_0-logloss:0.06807
# [269]	validation_0-logloss:0.06813
# [270]	validation_0-logloss:0.06809
# [271]	validation_0-logloss:0.06812
# [272]	validation_0-logloss:0.06811
# [273]	validation_0-logloss:0.06805
# [274]	validation_0-logloss:0.06793
# [275]	validation_0-logloss:0.06783
# [276]	validation_0-logloss:0.06779
# [277]	validation_0-logloss:0.06780
# [278]	validation_0-logloss:0.06773
# [279]	validation_0-logloss:0.06775
# [280]	validation_0-logloss:0.06773
# [281]	validation_0-logloss:0.06773
# [282]	validation_0-logloss:0.06762
# [283]	validation_0-logloss:0.06759
# [284]	validation_0-logloss:0.06738
# [285]	validation_0-logloss:0.06735
# [286]	validation_0-logloss:0.06746
# [287]	validation_0-logloss:0.06752
# [288]	validation_0-logloss:0.06754
# [289]	validation_0-logloss:0.06753
# [290]	validation_0-logloss:0.06756
# [291]	validation_0-logloss:0.06753
# [292]	validation_0-logloss:0.06760
# [293]	validation_0-logloss:0.06759
# [294]	validation_0-logloss:0.06755
# [295]	validation_0-logloss:0.06744
# [296]	validation_0-logloss:0.06739
# [297]	validation_0-logloss:0.06735
# [298]	validation_0-logloss:0.06727
# [299]	validation_0-logloss:0.06722
# [300]	validation_0-logloss:0.06718
# [301]	validation_0-logloss:0.06721
# [302]	validation_0-logloss:0.06719
# [303]	validation_0-logloss:0.06726
# [304]	validation_0-logloss:0.06730
# [305]	validation_0-logloss:0.06727
# [306]	validation_0-logloss:0.06725
# [307]	validation_0-logloss:0.06723
# [308]	validation_0-logloss:0.06716
# [309]	validation_0-logloss:0.06722
# [310]	validation_0-logloss:0.06723
# [311]	validation_0-logloss:0.06711
# [312]	validation_0-logloss:0.06720
# [313]	validation_0-logloss:0.06711
# [314]	validation_0-logloss:0.06711
# [315]	validation_0-logloss:0.06708
# [316]	validation_0-logloss:0.06710
# [317]	validation_0-logloss:0.06711
# [318]	validation_0-logloss:0.06716
# [319]	validation_0-logloss:0.06718
# [320]	validation_0-logloss:0.06716
# [321]	validation_0-logloss:0.06717
# [322]	validation_0-logloss:0.06721
# [323]	validation_0-logloss:0.06719
# [324]	validation_0-logloss:0.06723
# [325]	validation_0-logloss:0.06721
# [326]	validation_0-logloss:0.06721
# [327]	validation_0-logloss:0.06717
# [328]	validation_0-logloss:0.06705
# [329]	validation_0-logloss:0.06718
# [330]	validation_0-logloss:0.06716
# [331]	validation_0-logloss:0.06713
# [332]	validation_0-logloss:0.06713
# [333]	validation_0-logloss:0.06720
# [334]	validation_0-logloss:0.06720
# [335]	validation_0-logloss:0.06715
# [336]	validation_0-logloss:0.06710
# [337]	validation_0-logloss:0.06712
# [338]	validation_0-logloss:0.06708
# [339]	validation_0-logloss:0.06706
# [340]	validation_0-logloss:0.06706
# [341]	validation_0-logloss:0.06700
# [342]	validation_0-logloss:0.06703
# [343]	validation_0-logloss:0.06707
# [344]	validation_0-logloss:0.06707
# [345]	validation_0-logloss:0.06712
# [346]	validation_0-logloss:0.06712
# [347]	validation_0-logloss:0.06710
# [348]	validation_0-logloss:0.06718
# [349]	validation_0-logloss:0.06714
# [350]	validation_0-logloss:0.06725
# [351]	validation_0-logloss:0.06725
# [352]	validation_0-logloss:0.06728
# [353]	validation_0-logloss:0.06727
# [354]	validation_0-logloss:0.06727
# [355]	validation_0-logloss:0.06724
# [356]	validation_0-logloss:0.06728
# [357]	validation_0-logloss:0.06728
# [358]	validation_0-logloss:0.06720
# [359]	validation_0-logloss:0.06726
# [360]	validation_0-logloss:0.06729
# [361]	validation_0-logloss:0.06733
# [362]	validation_0-logloss:0.06729
# [363]	validation_0-logloss:0.06731
# [364]	validation_0-logloss:0.06731
# [365]	validation_0-logloss:0.06733
# [366]	validation_0-logloss:0.06733
# [367]	validation_0-logloss:0.06733
# [368]	validation_0-logloss:0.06732
# [369]	validation_0-logloss:0.06732
# [370]	validation_0-logloss:0.06732
# [371]	validation_0-logloss:0.06732
# [372]	validation_0-logloss:0.06731
# [373]	validation_0-logloss:0.06735
# [374]	validation_0-logloss:0.06724
# [375]	validation_0-logloss:0.06724
# [376]	validation_0-logloss:0.06724
# ...
# [557]	validation_0-mlogloss:0.17148
# [558]	validation_0-mlogloss:0.17143
# [559]	validation_0-mlogloss:0.17143
# [560]	validation_0-mlogloss:0.17143
# [561]	validation_0-mlogloss:0.17143
# [562]	validation_0-mlogloss:0.17143
# [563]	validation_0-mlogloss:0.17149
# [564]	validation_0-mlogloss:0.17144
# [565]	validation_0-mlogloss:0.17131
# [566]	validation_0-mlogloss:0.17131
# [567]	validation_0-mlogloss:0.17131
# [568]	validation_0-mlogloss:0.17133
# [569]	validation_0-mlogloss:0.17132
# [570]	validation_0-mlogloss:0.17132
# [571]	validation_0-mlogloss:0.17132
# [572]	validation_0-mlogloss:0.17132
# [573]	validation_0-mlogloss:0.17133
# [574]	validation_0-mlogloss:0.17133
# [575]	validation_0-mlogloss:0.17133
# [576]	validation_0-mlogloss:0.17136
# [577]	validation_0-mlogloss:0.17136
# [578]	validation_0-mlogloss:0.17136
# [579]	validation_0-mlogloss:0.17139
# [580]	validation_0-mlogloss:0.17142
# [581]	validation_0-mlogloss:0.17142
# [582]	validation_0-mlogloss:0.17142
# [583]	validation_0-mlogloss:0.17141
# [584]	validation_0-mlogloss:0.17139
# [585]	validation_0-mlogloss:0.17139
# [586]	validation_0-mlogloss:0.17146
# [587]	validation_0-mlogloss:0.17146
# [588]	validation_0-mlogloss:0.17142
# [589]	validation_0-mlogloss:0.17141
# [590]	validation_0-mlogloss:0.17141
# [591]	validation_0-mlogloss:0.17148
# [592]	validation_0-mlogloss:0.17154
# [593]	validation_0-mlogloss:0.17154
# [594]	validation_0-mlogloss:0.17154
# [595]	validation_0-mlogloss:0.17154
# [596]	validation_0-mlogloss:0.17154
# [597]	validation_0-mlogloss:0.17154
# [598]	validation_0-mlogloss:0.17154
# [599]	validation_0-mlogloss:0.17154
# [600]	validation_0-mlogloss:0.17154
# [601]	validation_0-mlogloss:0.17154
# [602]	validation_0-mlogloss:0.17154
# [603]	validation_0-mlogloss:0.17154
# [604]	validation_0-mlogloss:0.17145
# [605]	validation_0-mlogloss:0.17145
# [606]	validation_0-mlogloss:0.17145
# [607]	validation_0-mlogloss:0.17145
# [608]	validation_0-mlogloss:0.17145
# [609]	validation_0-mlogloss:0.17142
# [610]	validation_0-mlogloss:0.17142
# [611]	validation_0-mlogloss:0.17133
# [612]	validation_0-mlogloss:0.17129
# [613]	validation_0-mlogloss:0.17129
# [614]	validation_0-mlogloss:0.17129
# [615]	validation_0-mlogloss:0.17129
# [616]	validation_0-mlogloss:0.17128
# [617]	validation_0-mlogloss:0.17128
# [618]	validation_0-mlogloss:0.17122
# [619]	validation_0-mlogloss:0.17122
# [620]	validation_0-mlogloss:0.17122
# [621]	validation_0-mlogloss:0.17128
# [622]	validation_0-mlogloss:0.17128
# [623]	validation_0-mlogloss:0.17128
# [624]	validation_0-mlogloss:0.17128
# [625]	validation_0-mlogloss:0.17128
# [626]	validation_0-mlogloss:0.17123
# [627]	validation_0-mlogloss:0.17120
# [628]	validation_0-mlogloss:0.17120
# [629]	validation_0-mlogloss:0.17120
# [630]	validation_0-mlogloss:0.17125
# [631]	validation_0-mlogloss:0.17125
# [632]	validation_0-mlogloss:0.17125
# [633]	validation_0-mlogloss:0.17125
# [634]	validation_0-mlogloss:0.17125
# [635]	validation_0-mlogloss:0.17125
# [636]	validation_0-mlogloss:0.17121
# [637]	validation_0-mlogloss:0.17121
# [638]	validation_0-mlogloss:0.17107
# [639]	validation_0-mlogloss:0.17103
# [640]	validation_0-mlogloss:0.17103
# [641]	validation_0-mlogloss:0.17103
# [642]	validation_0-mlogloss:0.17100
# [643]	validation_0-mlogloss:0.17100
# [644]	validation_0-mlogloss:0.17099
# [645]	validation_0-mlogloss:0.17098
# [646]	validation_0-mlogloss:0.17098
# [647]	validation_0-mlogloss:0.17098
# [648]	validation_0-mlogloss:0.17098
# [649]	validation_0-mlogloss:0.17098
# [650]	validation_0-mlogloss:0.17098
# [651]	validation_0-mlogloss:0.17096
# [652]	validation_0-mlogloss:0.17092
# [653]	validation_0-mlogloss:0.17090
# [654]	validation_0-mlogloss:0.17099
# [655]	validation_0-mlogloss:0.17099
# [656]	validation_0-mlogloss:0.17099
# [657]	validation_0-mlogloss:0.17097
# [658]	validation_0-mlogloss:0.17097
# [659]	validation_0-mlogloss:0.17098
# [660]	validation_0-mlogloss:0.17096
# [661]	validation_0-mlogloss:0.17096
# [662]	validation_0-mlogloss:0.17096
# [663]	validation_0-mlogloss:0.17088
# [664]	validation_0-mlogloss:0.17088
# [665]	validation_0-mlogloss:0.17088
# [666]	validation_0-mlogloss:0.17088
# [667]	validation_0-mlogloss:0.17088
# [668]	validation_0-mlogloss:0.17088
# [669]	validation_0-mlogloss:0.17089
# [670]	validation_0-mlogloss:0.17089
# [671]	validation_0-mlogloss:0.17088
# [672]	validation_0-mlogloss:0.17088
# [673]	validation_0-mlogloss:0.17088
# [674]	validation_0-mlogloss:0.17088
# [675]	validation_0-mlogloss:0.17088
# [676]	validation_0-mlogloss:0.17088
# [677]	validation_0-mlogloss:0.17088
# [678]	validation_0-mlogloss:0.17094
# [679]	validation_0-mlogloss:0.17096
# [680]	validation_0-mlogloss:0.17097
# [681]	validation_0-mlogloss:0.17097
# [682]	validation_0-mlogloss:0.17092
# [683]	validation_0-mlogloss:0.17094
# [684]	validation_0-mlogloss:0.17094
# [685]	validation_0-mlogloss:0.17094
# [686]	validation_0-mlogloss:0.17094
# [687]	validation_0-mlogloss:0.17094
# [688]	validation_0-mlogloss:0.17094
# [689]	validation_0-mlogloss:0.17087
# [690]	validation_0-mlogloss:0.17087
# [691]	validation_0-mlogloss:0.17087
# [692]	validation_0-mlogloss:0.17087
# [693]	validation_0-mlogloss:0.17087
# [694]	validation_0-mlogloss:0.17087
# [695]	validation_0-mlogloss:0.17096
# [696]	validation_0-mlogloss:0.17100
# [697]	validation_0-mlogloss:0.17093
# [698]	validation_0-mlogloss:0.17093
# [699]	validation_0-mlogloss:0.17093
# [700]	validation_0-mlogloss:0.17085
# [701]	validation_0-mlogloss:0.17085
# [702]	validation_0-mlogloss:0.17085
# [703]	validation_0-mlogloss:0.17085
# [704]	validation_0-mlogloss:0.17085
# [705]	validation_0-mlogloss:0.17081
# [706]	validation_0-mlogloss:0.17082
# [707]	validation_0-mlogloss:0.17082
# [708]	validation_0-mlogloss:0.17082
# [709]	validation_0-mlogloss:0.17085
# [710]	validation_0-mlogloss:0.17085
# [711]	validation_0-mlogloss:0.17085
# [712]	validation_0-mlogloss:0.17085
# [713]	validation_0-mlogloss:0.17085
# [714]	validation_0-mlogloss:0.17083
# [715]	validation_0-mlogloss:0.17083
# [716]	validation_0-mlogloss:0.17079
# [717]	validation_0-mlogloss:0.17079
# [718]	validation_0-mlogloss:0.17079
# [719]	validation_0-mlogloss:0.17079
# [720]	validation_0-mlogloss:0.17079
# [721]	validation_0-mlogloss:0.17079
# [722]	validation_0-mlogloss:0.17079
# [723]	validation_0-mlogloss:0.17079
# [724]	validation_0-mlogloss:0.17080
# [725]	validation_0-mlogloss:0.17080
# [726]	validation_0-mlogloss:0.17080
# [727]	validation_0-mlogloss:0.17080
# [728]	validation_0-mlogloss:0.17080
# [729]	validation_0-mlogloss:0.17085
# [730]	validation_0-mlogloss:0.17085
# [731]	validation_0-mlogloss:0.17085
# [732]	validation_0-mlogloss:0.17086
# [733]	validation_0-mlogloss:0.17086
# [734]	validation_0-mlogloss:0.17086
# [735]	validation_0-mlogloss:0.17086
# [736]	validation_0-mlogloss:0.17086
# [737]	validation_0-mlogloss:0.17086
# [738]	validation_0-mlogloss:0.17082
# [739]	validation_0-mlogloss:0.17082
# [740]	validation_0-mlogloss:0.17082
# [741]	validation_0-mlogloss:0.17082
# [742]	validation_0-mlogloss:0.17082
# [743]	validation_0-mlogloss:0.17082
# [744]	validation_0-mlogloss:0.17086
# [745]	validation_0-mlogloss:0.17086
# [746]	validation_0-mlogloss:0.17087
# [747]	validation_0-mlogloss:0.17087
# [748]	validation_0-mlogloss:0.17089
# [749]	validation_0-mlogloss:0.17089
# [750]	validation_0-mlogloss:0.17088
# [751]	validation_0-mlogloss:0.17088
# [752]	validation_0-mlogloss:0.17086
# [753]	validation_0-mlogloss:0.17086
# [754]	validation_0-mlogloss:0.17086
# [755]	validation_0-mlogloss:0.17086
# [756]	validation_0-mlogloss:0.17086
# [757]	validation_0-mlogloss:0.17095
# [758]	validation_0-mlogloss:0.17090
# [759]	validation_0-mlogloss:0.17091
# [760]	validation_0-mlogloss:0.17091
# [761]	validation_0-mlogloss:0.17089
# [762]	validation_0-mlogloss:0.17089
# [763]	validation_0-mlogloss:0.17089
# [764]	validation_0-mlogloss:0.17089
# [765]	validation_0-mlogloss:0.17091
# [766]	validation_0-mlogloss:0.17091
# [767]	validation_0-mlogloss:0.17091
# [768]	validation_0-mlogloss:0.17091
# [769]	validation_0-mlogloss:0.17091
# [770]	validation_0-mlogloss:0.17091
# [771]	validation_0-mlogloss:0.17086
# [772]	validation_0-mlogloss:0.17088
# [773]	validation_0-mlogloss:0.17088
# [774]	validation_0-mlogloss:0.17088
# [775]	validation_0-mlogloss:0.17088
# [776]	validation_0-mlogloss:0.17088
# [777]	validation_0-mlogloss:0.17088
# [778]	validation_0-mlogloss:0.17088
# [779]	validation_0-mlogloss:0.17088
# [780]	validation_0-mlogloss:0.17088
# [781]	validation_0-mlogloss:0.17087
# [782]	validation_0-mlogloss:0.17082
# [783]	validation_0-mlogloss:0.17082
# [784]	validation_0-mlogloss:0.17082
# [785]	validation_0-mlogloss:0.17082
# [786]	validation_0-mlogloss:0.17082
# [787]	validation_0-mlogloss:0.17080
# [788]	validation_0-mlogloss:0.17080
# [789]	validation_0-mlogloss:0.17080
# [790]	validation_0-mlogloss:0.17080
# [791]	validation_0-mlogloss:0.17080
# [792]	validation_0-mlogloss:0.17082
# [793]	validation_0-mlogloss:0.17082
# [794]	validation_0-mlogloss:0.17076
# [795]	validation_0-mlogloss:0.17076
# [796]	validation_0-mlogloss:0.17078
# [797]	validation_0-mlogloss:0.17078
# [798]	validation_0-mlogloss:0.17078
# [799]	validation_0-mlogloss:0.17078
# [800]	validation_0-mlogloss:0.17074
# [801]	validation_0-mlogloss:0.17074
# [802]	validation_0-mlogloss:0.17074
# [803]	validation_0-mlogloss:0.17074
# [804]	validation_0-mlogloss:0.17074
# [805]	validation_0-mlogloss:0.17074
# [806]	validation_0-mlogloss:0.17074
# [807]	validation_0-mlogloss:0.17074
# [808]	validation_0-mlogloss:0.17073
# [809]	validation_0-mlogloss:0.17068
# [810]	validation_0-mlogloss:0.17068
# [811]	validation_0-mlogloss:0.17068
# [812]	validation_0-mlogloss:0.17065
# [813]	validation_0-mlogloss:0.17065
# [814]	validation_0-mlogloss:0.17065
# [815]	validation_0-mlogloss:0.17065
# [816]	validation_0-mlogloss:0.17065
# [817]	validation_0-mlogloss:0.17067
# [818]	validation_0-mlogloss:0.17066
# [819]	validation_0-mlogloss:0.17066
# [820]	validation_0-mlogloss:0.17066
# [821]	validation_0-mlogloss:0.17066
# [822]	validation_0-mlogloss:0.17066
# [823]	validation_0-mlogloss:0.17059
# [824]	validation_0-mlogloss:0.17059
# [825]	validation_0-mlogloss:0.17059
# [826]	validation_0-mlogloss:0.17059
# [827]	validation_0-mlogloss:0.17059
# [828]	validation_0-mlogloss:0.17059
# [829]	validation_0-mlogloss:0.17061
# [830]	validation_0-mlogloss:0.17061
# [831]	validation_0-mlogloss:0.17061
# [832]	validation_0-mlogloss:0.17061
# [833]	validation_0-mlogloss:0.17064
# [834]	validation_0-mlogloss:0.17064
# [835]	validation_0-mlogloss:0.17064
# [836]	validation_0-mlogloss:0.17064
# [837]	validation_0-mlogloss:0.17064
# [838]	validation_0-mlogloss:0.17064
# [839]	validation_0-mlogloss:0.17064
# [840]	validation_0-mlogloss:0.17064
# [841]	validation_0-mlogloss:0.17064
# [842]	validation_0-mlogloss:0.17064
# [843]	validation_0-mlogloss:0.17064
# [844]	validation_0-mlogloss:0.17064
# [845]	validation_0-mlogloss:0.17060
# [846]	validation_0-mlogloss:0.17060
# [847]	validation_0-mlogloss:0.17067
# [848]	validation_0-mlogloss:0.17067
# [849]	validation_0-mlogloss:0.17067
# [850]	validation_0-mlogloss:0.17067
# [851]	validation_0-mlogloss:0.17067
# [852]	validation_0-mlogloss:0.17068
# [853]	validation_0-mlogloss:0.17068
# [854]	validation_0-mlogloss:0.17068
# [855]	validation_0-mlogloss:0.17068
# [856]	validation_0-mlogloss:0.17068
# [857]	validation_0-mlogloss:0.17068
# [858]	validation_0-mlogloss:0.17068
# [859]	validation_0-mlogloss:0.17068
# [860]	validation_0-mlogloss:0.17068
# [861]	validation_0-mlogloss:0.17061
# [862]	validation_0-mlogloss:0.17061
# [863]	validation_0-mlogloss:0.17061
# [864]	validation_0-mlogloss:0.17063
# [865]	validation_0-mlogloss:0.17063
# [866]	validation_0-mlogloss:0.17063
# [867]	validation_0-mlogloss:0.17063
# [868]	validation_0-mlogloss:0.17065
# [869]	validation_0-mlogloss:0.17065
# [870]	validation_0-mlogloss:0.17065
# [871]	validation_0-mlogloss:0.17065
# [872]	validation_0-mlogloss:0.17065
# [873]	validation_0-mlogloss:0.17065
# [874]	validation_0-mlogloss:0.17065
# [875]	validation_0-mlogloss:0.17065
# [876]	validation_0-mlogloss:0.17065
# [877]	validation_0-mlogloss:0.17065
# [878]	validation_0-mlogloss:0.17065
# [879]	validation_0-mlogloss:0.17068
# [880]	validation_0-mlogloss:0.17068
# [881]	validation_0-mlogloss:0.17068
# [882]	validation_0-mlogloss:0.17071
# [883]	validation_0-mlogloss:0.17077
# [884]	validation_0-mlogloss:0.17077
# [885]	validation_0-mlogloss:0.17077
# [886]	validation_0-mlogloss:0.17077
# [887]	validation_0-mlogloss:0.17075
# [888]	validation_0-mlogloss:0.17075
# [889]	validation_0-mlogloss:0.17075
# [890]	validation_0-mlogloss:0.17075
# [891]	validation_0-mlogloss:0.17071
# [892]	validation_0-mlogloss:0.17069
# [893]	validation_0-mlogloss:0.17069
# [894]	validation_0-mlogloss:0.17069
# [895]	validation_0-mlogloss:0.17069
# [896]	validation_0-mlogloss:0.17070
# [897]	validation_0-mlogloss:0.17070
# [898]	validation_0-mlogloss:0.17070
# [899]	validation_0-mlogloss:0.17070
# [900]	validation_0-mlogloss:0.17070
# [901]	validation_0-mlogloss:0.17070
# [902]	validation_0-mlogloss:0.17070
# [903]	validation_0-mlogloss:0.17070
# [904]	validation_0-mlogloss:0.17070
# [905]	validation_0-mlogloss:0.17070
# [906]	validation_0-mlogloss:0.17070
# [907]	validation_0-mlogloss:0.17070
# [908]	validation_0-mlogloss:0.17070
# [909]	validation_0-mlogloss:0.17070
# [910]	validation_0-mlogloss:0.17070
# [911]	validation_0-mlogloss:0.17070
# [912]	validation_0-mlogloss:0.17070
# [913]	validation_0-mlogloss:0.17070
# [914]	validation_0-mlogloss:0.17070
# [915]	validation_0-mlogloss:0.17070
# [916]	validation_0-mlogloss:0.17070
# [917]	validation_0-mlogloss:0.17070
# [918]	validation_0-mlogloss:0.17066
# [919]	validation_0-mlogloss:0.17066
# [920]	validation_0-mlogloss:0.17066
# [921]	validation_0-mlogloss:0.17066
# [922]	validation_0-mlogloss:0.17066
# [923]	validation_0-mlogloss:0.17066
# [924]	validation_0-mlogloss:0.17066
# [925]	validation_0-mlogloss:0.17066
# [926]	validation_0-mlogloss:0.17066
# [927]	validation_0-mlogloss:0.17066
# [928]	validation_0-mlogloss:0.17071
# [929]	validation_0-mlogloss:0.17078
# [930]	validation_0-mlogloss:0.17078
# [931]	validation_0-mlogloss:0.17078
# [932]	validation_0-mlogloss:0.17078
# [933]	validation_0-mlogloss:0.17078
# [934]	validation_0-mlogloss:0.17075
# [935]	validation_0-mlogloss:0.17075
# [936]	validation_0-mlogloss:0.17075
# [937]	validation_0-mlogloss:0.17075
# [938]	validation_0-mlogloss:0.17075
# [939]	validation_0-mlogloss:0.17075
# [940]	validation_0-mlogloss:0.17074
# [941]	validation_0-mlogloss:0.17074
# [942]	validation_0-mlogloss:0.17074
# [943]	validation_0-mlogloss:0.17074
# [944]	validation_0-mlogloss:0.17074
# [945]	validation_0-mlogloss:0.17074
# [946]	validation_0-mlogloss:0.17074
# [947]	validation_0-mlogloss:0.17074
# [948]	validation_0-mlogloss:0.17074
# [949]	validation_0-mlogloss:0.17074
# [950]	validation_0-mlogloss:0.17074
# [951]	validation_0-mlogloss:0.17074
# [952]	validation_0-mlogloss:0.17074
# [953]	validation_0-mlogloss:0.17074
# [954]	validation_0-mlogloss:0.17074
# [955]	validation_0-mlogloss:0.17074
# [956]	validation_0-mlogloss:0.17067
# [957]	validation_0-mlogloss:0.17067
# [958]	validation_0-mlogloss:0.17067
# [959]	validation_0-mlogloss:0.17067
# [960]	validation_0-mlogloss:0.17068
# [961]	validation_0-mlogloss:0.17062
# [962]	validation_0-mlogloss:0.17062
# [963]	validation_0-mlogloss:0.17059
# [964]	validation_0-mlogloss:0.17059
# [965]	validation_0-mlogloss:0.17059
# [966]	validation_0-mlogloss:0.17059
# [967]	validation_0-mlogloss:0.17059
# [968]	validation_0-mlogloss:0.17048
# [969]	validation_0-mlogloss:0.17052
# [970]	validation_0-mlogloss:0.17059
# [971]	validation_0-mlogloss:0.17059
# [972]	validation_0-mlogloss:0.17059
# [973]	validation_0-mlogloss:0.17059
# [974]	validation_0-mlogloss:0.17059
# [975]	validation_0-mlogloss:0.17059
# [976]	validation_0-mlogloss:0.17059
# [977]	validation_0-mlogloss:0.17059
# [978]	validation_0-mlogloss:0.17059
# [979]	validation_0-mlogloss:0.17059
# [980]	validation_0-mlogloss:0.17059
# [981]	validation_0-mlogloss:0.17059
# [982]	validation_0-mlogloss:0.17059
# [983]	validation_0-mlogloss:0.17059
# [984]	validation_0-mlogloss:0.17059
# [985]	validation_0-mlogloss:0.17059
# [986]	validation_0-mlogloss:0.17059
# [987]	validation_0-mlogloss:0.17059
# [988]	validation_0-mlogloss:0.17059
# [989]	validation_0-mlogloss:0.17057
# [990]	validation_0-mlogloss:0.17057
# [991]	validation_0-mlogloss:0.17057
# [992]	validation_0-mlogloss:0.17057
# [993]	validation_0-mlogloss:0.17057
# [994]	validation_0-mlogloss:0.17057
# [995]	validation_0-mlogloss:0.17057
# [996]	validation_0-mlogloss:0.17055
# [997]	validation_0-mlogloss:0.17055
# [998]	validation_0-mlogloss:0.17055
# [999]	validation_0-mlogloss:0.17055
# Fold4 AUC = 0.994442
# Mean CV AUC = 0.995726

# %%
sub = pd.DataFrame({
    'unique_id':           test_info['unique_id'],
    'gender':              pred_gender,
    'hold racket handed':  pred_hand,
    # 'gender':              1 - pred_gender,
    # 'hold racket handed':  1 - pred_hand,
    'play years_0':        pred_years[:,0],
    'play years_1':        pred_years[:,1],
    'play years_2':        pred_years[:,2],
    'level_2':             pred_level[:,0],
    'level_3':             pred_level[:,1],
    'level_4':             pred_level[:,2],
    'level_5':             pred_level[:,3],
})
sub.to_csv("./output/XGboost_submission1.csv", index=False, float_format="%.6f")
print("✅ 已完成 submission.csv 輸出")
# Out:
# ✅ 已完成 submission.csv 輸出
